# %% [markdown]
# # 01. NumPy 시작하기

# %% [markdown]
# ## NumPy (Numerical Python) 라이브러리

# %% [markdown]
# ### 데이터 분석의 출발점이 되는, 빠르고 효율적인 수치 계산 도구

# %%
# Pandas, Matplotlib, SciPy, Scikit-learn을 포괄하고 있음

# C언어로 구성된 명령들(처리속도가 빠름)을 파이썬으로 감싸고 있음

# list 자료형으로 데이터를 저장하는 python의 단점:
    # (저장↓, 가공↓, 효율성↓, 처리속도↓)을 보완

# 특징: 계산속도 ↑, 간결한 코드

# 기능: 
    # 배열(array) 생성, 연산
    # 수학함수
    # 행렬 계산 (3차원 행렬(=Tensor))
    # 난수 생성

# %%
### NumPy의 핵심 자료구조: ndarray

# %%
# NumPy는 타입이 다른건 허용하지 않는다!

# ndarray: python에서 수치 데이터를 다루는 표준 형식
    # 배열 in python: NumPy ndarray
    # 형식: np.array([])

# 형태: 
    # 리스트: 순서 = index
    # 같은 자료형의 값 모음 = 수학적 표(행렬) 형태의 배열

# 리스트랑 배열은 앞으로 다른 용어임!
    # 배열 -> ndarray
