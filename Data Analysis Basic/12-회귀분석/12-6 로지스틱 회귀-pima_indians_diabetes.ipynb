# %% [markdown]
# # [LAB-12] 6. 로지스틱 회귀 - pima_indians_diabetes
#
# ## #01. 준비작업
#
# ### 1. 패키지 참조:

# %%
# 기본 참조
from hossam import load_data
from pandas import DataFrame, get_dummies
from matplotlib import pyplot as plt
from matplotlib import font_manager as fm
import seaborn as sb
import numpy as np

# 로지스틱 회귀용 참조
import statsmodels.api as sm

# 로지스틱 결과판정, 사후검정용 참조 
# (머신러닝 라이브러리 미리 사용함)
from sklearn.metrics import confusion_matrix, roc_curve, roc_auc_score, accuracy_score, recall_score, precision_score, f1_score

# VIF값 계산용 참조
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %% [markdown]
# ### 2. 그래프 초기화:

# %%
my_dpi = 200  # 이미지 선명도 (100~300)
font_path = r"\Users\itwill\OneDrive\문서\학원수업\NotoSansKR-Regular.ttf"  # 한글을 지원하는 폰트 파일의 경로
fm.fontManager.addfont(font_path)      # 폰트 글꼴을 시스템에 등록함
font_prop = fm.FontProperties(fname = font_path)    # 폰트 속성을 읽어옴
font_name = font_prop.get_name()    # 읽어온 속성에서 폰트의 이름만 추출

plt.rcParams['font.family'] = font_name # 그래프에 한글폰트 적용
plt.rcParams['font.size'] = 6          # 기본 폰트 크기
plt.rcParams['axes.unicode_minus'] = False  
    # 그래프에 마이너스 깨짐 방지 (한글 환경에선 필수)

# %% [markdown]
# ### 3. 데이터 가져오기:

# %%
origin = load_data('pima_indians_diabetes')

print("\n===== 데이터 크기 확인 =====")
print(f"데이터셋 크기: {origin.shape}")
print(f"열 갯수: {origin.shape[1]}")
print(f"행 갯수: {origin.shape[0]}")

print("\n===== 타입 확인 =====")
print(origin.info())

origin.head()
# Out:
# [data] https://data.hossam.kr/data/kaggle/pima_indians_diabetes.xlsx
# [desc] 이 데이터 세트는 원래 미국 국립 당뇨병·소화기·신장질환 연구소(National Institute of Diabetes and Digestive and Kidney Diseases)에서 제공한 것입니다. 이 데이터 세트의 목적은 데이터 세트에 포함된 특정 진단 측정값을 기반으로 환자의 당뇨병 여부를 진단적으로 예측하는 것입니다. 더 큰 데이터베이스에서 이러한 사례를 선택하는 데에는 몇 가지 제약 조건이 적용되었습니다. 특히, 여기에 포함된 모든 환자는 21세 이상의 피마 인디언 혈통을 가진 여성입니다. (출처: https://www.kaggle.com/datasets/uciml/pima-indians-diabetes-database)
#
# field                     type    description
# ------------------------  ------  --------------------------------
# Pregnancies               연속형  임신횟수
# Glucose                   연속형  포도당 부하 검사 수치
# BloodPressure             연속형  혈압
# SkinThickness             연속형  팔 삼두근 뒤쪽의 피하지방 측정값
# Insulin                   연속형  혈청 인슐린
# BMI                       연속형  체질량 지수
# DiabetesPedigreeFunction  연속형  당뇨 내력 가중치 값
# Age                       연속형  나이
# Outcome                   명목형  당뇨여부(0 또는 1)
#
#
# ===== 데이터 크기 확인 =====
# 데이터셋 크기: (768, 9)
# 열 갯수: 9
# ...

# %% [markdown]
# ## #02. 기본 분석
#
# - 데이터 전처리: 더미변수 처리(데이터 라벨링)만! (base model)
# - 사실상 로지스틱 회귀는 결과표의 값(ex. zscore, p-value)들이 중요한게 아니고 **직접 계산하는 오즈값**이 중요함!
#
# ### 1. 모델 구축:

# %%
yname = 'Outcome'               # 종속변수 이름

x = origin.drop(yname, axis=1)  # 독립변수만 추출(DataFrame 형태)
y = origin[yname]               # 종속변수만 추출(Series 형태)
X = sm.add_constant(x)          # 독립변수에 상수항 추가

fit = sm.Logit(y, X).fit()
tbl1 = fit.summary()
print(tbl1)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.470993
#          Iterations 6
#                            Logit Regression Results
# ...
# Dep. Variable:                Outcome   No. Observations:                  768
# Model:                          Logit   Df Residuals:                      759
# Method:                           MLE   Df Model:                            8
# Date:                   화, 16 12 2025   Pseudo R-squ.:                  0.2718
# Time:                        10:15:56   Log-Likelihood:                -361.72
# converged:                       True   LL-Null:                       -496.74
# Covariance Type:            nonrobust   LLR p-value:                 9.652e-54
# ...
#                                coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# - 결과표에서 p-value는 딱히 필요 없음
# - VIF도 (이유: VIF는 선형성일 때 사용하는 값)
#
# ### 2. 결과보고 함수 정의
#
# in 성능평가지표:
# - VIF 계산에서 `for i, col in~`보다 `col: variance~`가 먼저 오는 이유:
#   - `VIF{}` 안에 위 두 줄 넣으면서 축약하면서 순서 바뀐거임
# - `or_val`: 오즈값 (그 아래는 오즈값에 대한 신뢰구간 범위임)

# %%
def logit_report(fit, data, threshold=0.5):
    """
    Logit summary(tbl)와 데이터프레임(data)을 받아
    회귀계수(rdf),
    모델 적합도 요약표(result_report),
    모형 보고 문장(model_report),
    변수 별 보고리스트(variable_reports)를 반환한다.
    """

    # -------------------------------------------
    # 1. 성능 평가 지표
    # -------------------------------------------
    yname = fit.model.endog_names
    y_true = data[yname]
    y_pred = fit.predict(fit.model.exog)
    y_pred_fix = (y_pred >= threshold).astype(int) # true=1,false=0

    # 혼동행렬
    cm = confusion_matrix(y_true, y_pred_fix)
    tn, fp, fn, tp = cm.ravel()

    acc = accuracy_score(y_true, y_pred_fix)       # 정확도
    pre = precision_score(y_true, y_pred_fix)      # 정밀도
    tpr = recall_score(y_true, y_pred_fix)         # 재현율
    fpr = fp / (fp + tn)                           # 위양성률
    tnr = 1 - fpr                                  # 특이성
    f1 = f1_score(y_true, y_pred_fix)              # f1-score
    ras = roc_auc_score(y_true, y_pred)            # auc score

    cdf = DataFrame({
        '설명력(P-Rsqe)': [fit.prsquared],
        '정확도(Accuracy)': [acc],
        '정밀도(Precision)': [pre],
        '재현율(Recell, TPR)': [tpr],
        '위양성률(Fallout, FPR)': [fpr],
        '특이성(Specificity, TNR)': [tnr],
        'RAS(auc score)': [ras],
        'F1': [f1]
    })

    # -------------------------------------------
    # 2. 회귀계수 표 생성 (Odd Rate(OR) 중심)
    # -------------------------------------------
    tbl = fit.summary()

    # 종속변수 이름:
    yname = fit.model.endog_names

    # 독립변수 이름(상수항 제외):
    xnames = [n for n in fit.model.exog_names if n != 'const']

    # 독립변수:
    x = data[xnames]
    variables = []

    # VIF 계산:
    vif_dict = {
        col: variance_inflation_factor(x.values, i)
        for i, col in enumerate(x.columns)
    }

    for v in tbl.tables[1].data:
        name = v[0].strip()
        if name not in xnames:
            continue

        beta = float(v[1])
        se = float(v[2])
        z = float(v[3])
        p = float(v[4])

        or_val = np.exp(beta)
        ci_low = np.exp(beta - 1.96*se)
        ci_high = np.exp(beta + 1.96*se)

        stars = (
            "***" if p < 0.001 else
            "**" if p < 0.01 else
            "*" if p < 0.05 else
            ""
        )

        variables.append({
            "종속변수": yname,
            "독립변수": name,
            "B(β)": beta,
            "표준오차": se,
            "z-score": f"{z:.3f}{stars}",
            "p-value": p,
            "OR": or_val,
            "CI_lower": ci_low,
            "CI_upper": ci_high,
            "VIF": vif_dict.get(name, np.nan)
        })

        rdf = DataFrame(variables)

    # -------------------------------------------
    # 3. 모델적합도 + 예측성능 지표
    # -------------------------------------------
    y_true = data[yname]
    y_prob = fit.predict(fit.model.exog)
    y_pred = (y_prob >= threshold).astype(int)

    tn, fp, fn, tp = confusion_matrix(y_true, y_pred).ravel()

    acc = accuracy_score(y_true, y_pred)       # 정확도
    pre = precision_score(y_true, y_pred)      # 정밀도
    rec = recall_score(y_true, y_pred)         # 재현율
    f1 = f1_score(y_true, y_pred)              # f1-score
    auc = roc_auc_score(y_true, y_pred)        # auc score

    result_report = (
        f"Pseudo R²(McFadden) = {fit.prsquared:.3f},",
        f"LLR X²({int(fit.df_model)}) = {fit.llr:.3f},",
        f"p-value = {fit.llr_pvalue:.4f},",
        f"Accuracy = {acc:.3f},",
        f"AUC = {auc:.3f},"
    )

    # -------------------------------------------
    # 4. 모형 보고 문장
    # -------------------------------------------
    tpl = (
        "%s에 대하여 %s로 예측하는 로지스틱 회귀분석을 실시한 결과,"
        "모형은 통계적으로 %s(X²(%s) = %.3f, p %s 0.05) 하였다."
    )

    model_report = tpl % (
        yname,
        ", ".join(xnames),
        "유의" if fit.llr_pvalue <= 0.05 else "유의하지 않음",
        int(fit.df_model),
        fit.llr,
        "≤" if fit.llr_pvalue <= 0.05 else ">"
    )

    # -------------------------------------------
    # 5. 변수 별 보고문장
    # -------------------------------------------
    variable_reports = []

    s = (
        "%s의 오즈비는 %.3f(p %s 0.05)로,"
        "%s 발생 odds에 %s 영향을 미치는 것으로 나타났다."
    )

    for _, row in rdf.iterrows():
        variable_reports.append(
            s % (
                row["독립변수"],
                row["OR"],
                "≤" if row["p-value"] < 0.05 else ">",
                row["종속변수"],
                "유의미한" if row["p-value"] < 0.05 else "유의하지 않은"
            )
        )
    
    return cdf, rdf, result_report, model_report, variable_reports

# %% [markdown]
# ### 3. 분석결과 보고
#
# - 결과표에서 p-value는 딱히 필요 없음
# - VIF도 (이유: VIF는 선형성일 때 사용하는 값)

# %%
cdf, rdf, r, m, v = logit_report(fit, origin)
display(cdf)
display(rdf)
display(r)
display(m)
display(v)
# Out:
#    설명력(P-Rsqe)  정확도(Accuracy)  정밀도(Precision)  재현율(Recell, TPR)  \
# 0      0.27181       0.782552        0.739336           0.58209
#
#    위양성률(Fallout, FPR)  특이성(Specificity, TNR)  RAS(auc score)        F1
# 0                0.11                   0.89        0.839425  0.651357
#       종속변수                      독립변수    B(β)   표준오차   z-score  p-value  \
# 0  Outcome               Pregnancies  0.1232  0.032  3.840***    0.000
# 1  Outcome                   Glucose  0.0352  0.004  9.481***    0.000
# 2  Outcome             BloodPressure -0.0133  0.005   -2.540*    0.011
# 3  Outcome             SkinThickness  0.0006  0.007     0.090    0.929
# 4  Outcome                   Insulin -0.0012  0.001    -1.322    0.186
# 5  Outcome                       BMI  0.0897  0.015  5.945***    0.000
# 6  Outcome  DiabetesPedigreeFunction  0.9452  0.299   3.160**    0.002
# 7  Outcome                       Age  0.0149  0.009     1.593    0.111
#
#          OR  CI_lower  CI_upper        VIF
# ...

# %% [markdown]
# > 로지스틱에서 VIF는 참고용일 뿐, VIF가 10을 넘는다고 해서 제거할 필욘 없다
#
# ### 4. AUC 시각화

# %%
y_true = origin[yname]
y_prob = fit.predict(fit.model.exog)
y_pred = (y_prob >= 0.5).astype(int)

ras = roc_auc_score(y_true, y_pred)

roc_fpr, roc_tpr, thresholds = roc_curve(y_true, y_pred)

# 1) 그래프 초기화 
width_px = 1280                    # 그래프 가로 크기
height_px = 720                    # 그래프 세로 크기
rows = 1                           # 그래프 행 수
cols = 1                           # 그래프 열 수
figsize = (width_px / my_dpi, height_px / my_dpi)
fig, ax = plt.subplots(rows, cols, figsize = figsize, dpi = my_dpi)

# 2) lineplot 그래프 그리기 (w/ seaborn 사용)
sb.lineplot(x=roc_fpr, y=roc_tpr)
sb.lineplot(x = [0, 1], y = [0, 1],
            color = "red", linestyle = ':', 
            alpha=0.5)

# 3) 그래프 꾸미기: 
ax.set_title(f"AUC={ras:.4f}", pad=4, fontsize=10)
ax.grid(True, alpha=0.3)          # 배경, 격자 표시/숨김

# 4) 출력
plt.tight_layout()                # 여백 제거
plt.show()                        # 그래프 화면 출력
plt.close()                       # 그래프 작업 종료

# %% [markdown]
# ## #03. 독립변수 로그 변환
#
# - 회귀분석 필수: 로그변환이 필요한지 여부 확인
#     - 선형회귀에서는 VIF 실행 전에 로그변환 독립변수의 결과 성능 먼저 체크한 후 둘 중(변환 전, 후) 뭐가 더 나은 결과인지 판단 후 채택
#     - 로지스틱회귀도 마찬가지 이유로서 독립변수 로그변환 한 결과값 내보는거임
#
# ### 1. 로그 변환 결과도 분석하기:

# %%
# 1. 복사
df = origin.copy()

# 2. 종속 / 독립 변수:
yname = 'Outcome'
y = df[yname]
x = df.drop(columns=[yname])

# 3. 로그변환 대산 변수 (연속형만 명시)
log_vars = x.columns

# 4. 로그변환 (0값 대응)
for v in log_vars:
    df[f"log_{v}"] = np.log1p(df[v])

# 5. 원 변수 제거
df.drop(columns=log_vars, inplace=True)

# 6. 로지스틱 회귀
X_log = df.drop(columns=[yname])
X = sm.add_constant(X_log)

fit = sm.Logit(y, X).fit()
print(fit.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.516943
#          Iterations 7
#                            Logit Regression Results
# ...
# Dep. Variable:                Outcome   No. Observations:                  768
# Model:                          Logit   Df Residuals:                      759
# Method:                           MLE   Df Model:                            8
# Date:                   화, 16 12 2025   Pseudo R-squ.:                  0.2008
# Time:                        11:19:33   Log-Likelihood:                -397.01
# converged:                       True   LL-Null:                       -496.74
# Covariance Type:            nonrobust   LLR p-value:                 8.305e-39
# ...
#                                    coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# ...

# %%
cdf, rdf, r, m, v = logit_report(fit, df)
display(cdf)
display(rdf)
display(r)
display(m)
display(v)
# Out:
#    설명력(P-Rsqe)  정확도(Accuracy)  정밀도(Precision)  재현율(Recell, TPR)  \
# 0     0.200768       0.769531        0.719807           0.55597
#
#    위양성률(Fallout, FPR)  특이성(Specificity, TNR)  RAS(auc score)        F1
# 0               0.116                  0.884        0.836187  0.627368
#       종속변수                          독립변수    B(β)   표준오차   z-score  p-value  \
# 0  Outcome               log_Pregnancies  0.3125  0.136    2.305*    0.021
# 1  Outcome                   log_Glucose  2.9775  0.404  7.366***    0.000
# 2  Outcome             log_BloodPressure -0.2716  0.106   -2.562*    0.010
# 3  Outcome             log_SkinThickness  0.0359  0.077     0.469    0.639
# 4  Outcome                   log_Insulin -0.0416  0.047    -0.879    0.379
# 5  Outcome                       log_BMI  1.9870  0.467  4.253***    0.000
# 6  Outcome  log_DiabetesPedigreeFunction  1.6688  0.452  3.689***    0.000
# 7  Outcome                       log_Age  1.1022  0.342   3.220**    0.001
#
# ...

# %% [markdown]
# ### 2. AUC 시각화:

# %%
y_true = df[yname]
y_prob = fit.predict(fit.model.exog)
y_pred = (y_prob >= 0.5).astype(int)

ras = roc_auc_score(y_true, y_pred)

roc_fpr, roc_tpr, thresholds = roc_curve(y_true, y_pred)

# 1) 그래프 초기화 
width_px = 1280                    # 그래프 가로 크기
height_px = 720                    # 그래프 세로 크기
rows = 1                           # 그래프 행 수
cols = 1                           # 그래프 열 수
figsize = (width_px / my_dpi, height_px / my_dpi)
fig, ax = plt.subplots(rows, cols, figsize = figsize, dpi = my_dpi)

# 2) lineplot 그래프 그리기 (w/ seaborn 사용)
sb.lineplot(x=roc_fpr, y=roc_tpr)
sb.lineplot(x = [0, 1], y = [0, 1],
            color = "red", linestyle = ':', 
            alpha=0.5)

# 3) 그래프 꾸미기: 
ax.set_title(f"AUC={ras:.4f}", pad=4, fontsize=10)
ax.grid(True, alpha=0.3)          # 배경, 격자 표시/숨김

# 4) 출력
plt.tight_layout()                # 여백 제거
plt.show()                        # 그래프 화면 출력
plt.close()                       # 그래프 작업 종료

# %% [markdown]
# > 이 데이터와 이 연구 질문에서는 로그 변환(AUC = 0.72)이 적합하지 않았다 (기존 AUC = 0.736)
