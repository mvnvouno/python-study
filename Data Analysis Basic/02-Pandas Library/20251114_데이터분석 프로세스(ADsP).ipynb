# %%
# 모수 : 통상적으로 '모평균'을 뜻함
# VS
# 통계량 : 기술통계량 다지만, 통상적으로 '표본평균'을 뜻함

# 연구범위의 모집단과 표본집단 설정 방법: 
    # 시간적 범위설정 (->모집단) -> 공간적 범위설정 (->표본집단)
    # EX) 어느 지역에서 (:표본집단) 몇세 사이의 누구 (:모집단) 
    # -> 모집단과 표본집단의 선정 기준이 어떻게 되느냐에 따라서 동일한 데이터도 다르게잡힐 수 있음

# 데이터 뽑기 좋은 사이트 추천: 한국복지 패널

# 추정량(ESTIMATOR): 표본_평균/중앙/사분위수 등 에서 
    # 모집단_평균/중앙/사분위수를 추정하기 위한 계산식
    # -> 추후 머신러닝에서 에스티메이터 용어 많이 쓰일 예정

# 데이터: 관찰값, 관측값

# 다 같은 용어임 (주의):
    # COLUMN (in 표) = VARIABLES (column in DataFrame) = FEATURE(in 머신러닝)

# 변수의 종류 (EDA에 영향 줌)
    # 범주형 변수 (질적변수)
        # 통계값: 
            # 명목척도: 최빈값
            # 서열척도: 최빈값, 중앙값, 부등호비교
    # 연속형 변수 (수치형변수)
        # 통계값: 
            # 등간척도: 모든 연산 (ex. 최빈값, 중앙값) + 산술평균
                # 등간척도는 서열척도 중 '항목들 간 간격이 일정한 척도임
                # 리커드만 척도는 서열척도 중 항목간격 일정 안한 것 중에서 강제로 간격을 일정하게 만드는거임
                    # ex. 설문조사의 매우만족/만족/보통/불만족/매우불만족
            # 비율척도: 모든 연산 (ex. 최빈값, 중앙값) + 조화평균 + 기하평균
    # for 데이터분석가: 크개 독립변수(x)랑 종속변수(y)로 나뉨
        # y = ax + b (a: 가중치, b: 편향)

# 데이터분석 프로세스: 
# 1. 수집 -> 2. 전처리 -> 3. 피쳐 엔지니어링(머신러닝 성격) -> 4. 탐색적 데이터 분석 -> 5. 확증적 데이터 분석 -> 6. 데이터 모델링(머신러닝)
# 2. ex) 데이터 라벨링 in 자연어 처리 
# 4. ex) 기술통계, 시각화
