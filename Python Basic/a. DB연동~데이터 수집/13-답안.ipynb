# %% [markdown]
# # 파이썬 파이널 과제 풀이

# %%
# 데이터셋 ≒ 데이터 마트 ≒ 테이블 개념
    # 데이터분석가 신입 주니어로 입사하면: 
        # 데이터셋 구축하는 업무 주로 받음
# 데이터 웨어하우스 ≒ 데이터베이스 개념

# %% [markdown]
# ## 01. 패키지 참조

# %%
import requests
from pandas import DataFrame
from concurrent import futures

# %% [markdown]
# ## 02. CSV 파일 읽어오기

# %%
with open("서울교통공사_역주소 및 전화번호_20250318 (1).csv", "r", encoding="euc-kr") as f:
    csv_list = f.readlines()

print(csv_list[:5])
# Out:
# ['연번,역번호,호선,역명,역전화번호,도로명주소,지번주소\n', '1,150,1,서울,02-6110-1331,서울특별시 중구 세종대로 지하2(남대문로 5가),서울특별시 중구 남대문로5가 73-6 서울역(1호선)\n', '2,151,1,시청,02-6110-1321,서울특별시 중구 세종대로 지하101(정동),서울특별시 중구 정동 5-5 시청역(1호선)\n', '3,152,1,종각,02-6110-1311,서울특별시 종로구 종로 지하55(종로1가),서울특별시 종로구 종로1가 54 종각역(1호선)\n', '4,153,1,종로3가,02-6110-1301,서울특별시 종로구 종로 지하129(종로3가),서울특별시 종로구 종로3가 10-5 종로3가역(1호선)\n']

# %% [markdown]
# ## 03. OpenAPI data request 스펙 확인

# %% [markdown]
# ### 요청 정보 확인 (확인용)

# %%
# 요청 URL
url = "https://api.vworld.kr/req/address"

# QueryString 요청변수
params = {
            "service": "address",
            "request": "GetCoord",
            "crs": "epsg:4326",
            "address": "판교로 242",
            "format": "json",
            "type": "ROAD",
            "key": "A9FEA51E-B101-3762-AE06-592EED1EE5DE"
        }

# %% [markdown]
# ### 웹 데이터 요청하기

# %%
with requests.Session() as session:
    session.headers.update({
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36"
    })

    r = session.get(url, params=params)

    if r.status_code != 200:
        msg = "[%d error] %s 에러가 발생함" % (r.status_code, r.reason)
        raise Exception(msg)
        
    print(r)
# Out:
# <Response [200]>

# %% [markdown]
# ### 결과 데이터 확인

# %%
mydict = r.json()
mydict
# Out:
# {'response': {'service': {'name': 'address',
#    'version': '2.0',
#    'operation': 'GetCoord',
#    'time': '18(ms)'},
#   'status': 'OK',
#   'input': {'type': 'ROAD', 'address': '판교로 242'},
#   'refined': {'text': '경기도 성남시 분당구 판교로 242 (삼평동)',
#    'structure': {'level0': '대한민국',
#     'level1': '경기도',
#     'level2': '성남시 분당구',
#     'level3': '삼평동',
#     'level4L': '판교로',
#     'level4LC': '',
#     'level4A': '삼평동',
#     'level4AC': '4113565500',
#     'level5': '242',
#     'detail': ''}},
#   'result': {'crs': 'EPSG:4326',
#    'point': {'x': '127.101313354', 'y': '37.402352535'}}}}

# %% [markdown]
# ### 위경도 추출

# %%
point = mydict['response']['result']["point"]
print(point['x'], point['y'])
# Out:
# 127.101313354 37.402352535

# %% [markdown]
# ## 04. 위경도 조회 함수 짜기

# %%
def get_point(addr, type="road"): #기본값=road (비동기 처리할 때 type 변환 있을거라 변수로 지정한거임)
    #요청 url
    url = "https://api.vworld.kr/req/address"

    # QueryString 요청변수
    params = {
        "service": "address",
        "request": "GetCoord",
        "crs": "epsg:4326",
        "address": addr,
        "format": "json",
        "type": type, #비동기 처리할 때 type 변환 있을거라 변수로 지정한거임
        "key": "A9FEA51E-B101-3762-AE06-592EED1EE5DE"
    }

    with requests.Session() as session:
        session.headers.update({
            "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36"
        })

        r = session.get(url, params=params)

        if r.status_code != 200:
            msg = "[%d error] %s 에러가 발생함" % (r.status_code, r.reason)
            raise Exception(msg)

    mydict = r.json()
    point = mydict['response']['result']["point"]
    return (point['x'], point['y'])

# %% [markdown]
# ## 05. 위경도 변환하기

# %% [markdown]
# ### 1) 동기식 처리 ver.

# %%
size = len(csv_list)
resultset = []      # 결과 저장용 빈 리스트

# 약식으로 10건만 진행 (걸리는 시간만 보려고, 시간이슈)
# for i, v in enumerate(csv_list[1:]):
for i, v in enumerate(csv_list[1:11]):
    print("%d/%d 진행중..." % (i+1, size))
    items = v.strip().split(",")

    try:
        lat, lon = get_point(items[5])
    except Exception as e:
        # 도로명 주소로 실패했다면 지번 주소로 츄라이
        try:
            lat, lon = get_point(items[6], type="parcel")
        except Exception as e2:
            lat = None
            lon = None
    
    items.append(lat)
    items.append(lon)
    resultset.append(items)

resultset
# Out:
# 1/290 진행중...
# 2/290 진행중...
# 3/290 진행중...
# 4/290 진행중...
# 5/290 진행중...
# 6/290 진행중...
# 7/290 진행중...
# 8/290 진행중...
# 9/290 진행중...
# 10/290 진행중...
# [['1',
#   '150',
#   '1',
#   '서울',
#   '02-6110-1331',
#   '서울특별시 중구 세종대로 지하2(남대문로 5가)',
#   '서울특별시 중구 남대문로5가 73-6 서울역(1호선)',
#   '126.97254323694754',
#   '37.55702928798156'],
#  ['2',
#   '151',
#   '1',
#   '시청',
#   '02-6110-1321',
#   '서울특별시 중구 세종대로 지하101(정동)',
#   '서울특별시 중구 정동 5-5 시청역(1호선)',
#   '126.978346780',
#   '37.566700969'],
#  ['3',
#   '152',
#   '1',
#   '종각',
#   '02-6110-1311',
#   '서울특별시 종로구 종로 지하55(종로1가)',
#   '서울특별시 종로구 종로1가 54 종각역(1호선)',
#   '127.022379505',
#   '37.573411520'],
#  ['4',
#   '153',
#   '1',
#   '종로3가',
#   '02-6110-1301',
#   '서울특별시 종로구 종로 지하129(종로3가)',
#   '서울특별시 종로구 종로3가 10-5 종로3가역(1호선)',
#   '127.022379505',
#   '37.573411520'],
#  ['5',
#   '154',
#   '1',
#   '종로5가',
#   '02-6110-1291',
#   '서울특별시 종로구 종로 지하216(종로5가)',
#   '서울특별시 종로구 종로5가 82-1 종로5가역(1호선)',
#   '127.022379505',
#   '37.573411520'],
#  ['6',
#   '155',
#   '1',
#   '동대문',
#   '02-6110-1281',
#   '서울특별시 종로구 종로 지하302(창신동)',
#   '서울특별시 종로구 창신동 492-1 동대문역(1호선)',
#   '127.022379505',
#   '37.573411520'],
#  ['7',
#   '156',
#   '1',
#   '신설동',
#   '02-6110-1261',
#   '서울특별시 동대문구 왕산로 지하1(신설동)',
#   '서울특별시 동대문구 신설동 76-5 신설동역(1호선)',
#   '127.025093705',
#   '37.574718822'],
#  ['8',
#   '157',
#   '1',
#   '제기동',
#   '02-6110-1251',
#   '서울특별시 동대문구 왕산로 지하93(제기동)',
#   '서울특별시 동대문구 제기동 65 제기동역(1호선)',
#   '127.026716062',
#   '37.576899695'],
#  ['9',
#   '158',
#   '1',
#   '청량리(서울시립대입구)',
#   '02-6110-1241',
#   '서울특별시 동대문구 왕산로 지하205(전농동)',
#   '서울특별시 동대문구 전농동 620-69 청량리역(1호선)',
#   '127.026716062',
#   '37.576899695'],
#  ['10',
#   '159',
#   '1',
#   '동묘앞',
#   '02-6110-1271',
#   '서울특별시 종로구 종로 359(숭인동)',
#   '서울특별시 종로구 숭인동 117 동묘앞역(1호선)',
#   '127.017046549',
#   '37.573421235']]

# %% [markdown]
# ### 2) 비동기 처리 ver

# %%
size = len(csv_list)
processes = []      # 비동기 과정을 저장할 리스트
resultset = []      # 비동기 작업결과를 저장할 리스트

with futures.ThreadPoolExecutor(max_workers=30) as executor:
    for i, v in enumerate(csv_list[1:]):
        print("%d/%d 진행중..." % (i+1, size))
        items = v.strip().split(",")

        pro = executor.submit(get_point, items[5])  # 비동기 작업 생성
        processes.append(pro)
    
    for i, p in enumerate(processes):
        try:
            # try~except: 비동기 처리가 실행되는 동안 발생하는 예외 대비문
            lat, lon = p.result()
        except Exception as e:
            try:
                lat, lon = get_point(items[6], type="parcel")
            except Exception as e2:
                lat = None
                lon = None

        # 새로운 반복문이므로 직전 반복문에서 생성한 items 변수가 유효하지 않음
        # -> items 변수를 새로 생성해야함
        items = csv_list[i].strip().split(",")
        items.append(lat)
        items.append(lon)
        resultset.append(items)

resultset
# Out:
# 1/290 진행중...
# 2/290 진행중...
# 3/290 진행중...
# 4/290 진행중...
# 5/290 진행중...
# 6/290 진행중...
# 7/290 진행중...
# 8/290 진행중...
# 9/290 진행중...
# 10/290 진행중...
# 11/290 진행중...
# 12/290 진행중...
# 13/290 진행중...
# 14/290 진행중...
# 15/290 진행중...
# 16/290 진행중...
# 17/290 진행중...
# 18/290 진행중...
# 19/290 진행중...
# 20/290 진행중...
# 21/290 진행중...
# 22/290 진행중...
# 23/290 진행중...
# 24/290 진행중...
# 25/290 진행중...
# 26/290 진행중...
# 27/290 진행중...
# 28/290 진행중...
# 29/290 진행중...
# 30/290 진행중...
# 31/290 진행중...
# 32/290 진행중...
# 33/290 진행중...
# 34/290 진행중...
# 35/290 진행중...
# 36/290 진행중...
# 37/290 진행중...
# 38/290 진행중...
# 39/290 진행중...
# 40/290 진행중...
# 41/290 진행중...
# 42/290 진행중...
# 43/290 진행중...
# 44/290 진행중...
# 45/290 진행중...
# 46/290 진행중...
# 47/290 진행중...
# 48/290 진행중...
# 49/290 진행중...
# 50/290 진행중...
# 51/290 진행중...
# 52/290 진행중...
# 53/290 진행중...
# 54/290 진행중...
# 55/290 진행중...
# 56/290 진행중...
# 57/290 진행중...
# 58/290 진행중...
# 59/290 진행중...
# 60/290 진행중...
# 61/290 진행중...
# 62/290 진행중...
# 63/290 진행중...
# 64/290 진행중...
# 65/290 진행중...
# 66/290 진행중...
# 67/290 진행중...
# 68/290 진행중...
# 69/290 진행중...
# 70/290 진행중...
# 71/290 진행중...
# 72/290 진행중...
# 73/290 진행중...
# 74/290 진행중...
# 75/290 진행중...
# 76/290 진행중...
# 77/290 진행중...
# 78/290 진행중...
# 79/290 진행중...
# 80/290 진행중...
# 81/290 진행중...
# 82/290 진행중...
# 83/290 진행중...
# 84/290 진행중...
# 85/290 진행중...
# 86/290 진행중...
# 87/290 진행중...
# 88/290 진행중...
# 89/290 진행중...
# 90/290 진행중...
# 91/290 진행중...
# 92/290 진행중...
# 93/290 진행중...
# 94/290 진행중...
# 95/290 진행중...
# 96/290 진행중...
# 97/290 진행중...
# 98/290 진행중...
# 99/290 진행중...
# 100/290 진행중...
# 101/290 진행중...
# 102/290 진행중...
# 103/290 진행중...
# 104/290 진행중...
# 105/290 진행중...
# 106/290 진행중...
# 107/290 진행중...
# 108/290 진행중...
# 109/290 진행중...
# 110/290 진행중...
# 111/290 진행중...
# 112/290 진행중...
# 113/290 진행중...
# 114/290 진행중...
# 115/290 진행중...
# 116/290 진행중...
# 117/290 진행중...
# 118/290 진행중...
# 119/290 진행중...
# 120/290 진행중...
# 121/290 진행중...
# 122/290 진행중...
# 123/290 진행중...
# 124/290 진행중...
# 125/290 진행중...
# 126/290 진행중...
# 127/290 진행중...
# 128/290 진행중...
# 129/290 진행중...
# 130/290 진행중...
# 131/290 진행중...
# 132/290 진행중...
# 133/290 진행중...
# 134/290 진행중...
# 135/290 진행중...
# 136/290 진행중...
# 137/290 진행중...
# 138/290 진행중...
# 139/290 진행중...
# 140/290 진행중...
# 141/290 진행중...
# 142/290 진행중...
# 143/290 진행중...
# 144/290 진행중...
# 145/290 진행중...
# 146/290 진행중...
# 147/290 진행중...
# 148/290 진행중...
# 149/290 진행중...
# 150/290 진행중...
# 151/290 진행중...
# 152/290 진행중...
# 153/290 진행중...
# 154/290 진행중...
# 155/290 진행중...
# 156/290 진행중...
# 157/290 진행중...
# 158/290 진행중...
# 159/290 진행중...
# 160/290 진행중...
# 161/290 진행중...
# 162/290 진행중...
# 163/290 진행중...
# 164/290 진행중...
# 165/290 진행중...
# 166/290 진행중...
# 167/290 진행중...
# 168/290 진행중...
# 169/290 진행중...
# 170/290 진행중...
# 171/290 진행중...
# 172/290 진행중...
# 173/290 진행중...
# 174/290 진행중...
# 175/290 진행중...
# 176/290 진행중...
# 177/290 진행중...
# 178/290 진행중...
# 179/290 진행중...
# 180/290 진행중...
# 181/290 진행중...
# 182/290 진행중...
# 183/290 진행중...
# 184/290 진행중...
# 185/290 진행중...
# 186/290 진행중...
# 187/290 진행중...
# 188/290 진행중...
# 189/290 진행중...
# 190/290 진행중...
# 191/290 진행중...
# 192/290 진행중...
# 193/290 진행중...
# 194/290 진행중...
# 195/290 진행중...
# 196/290 진행중...
# 197/290 진행중...
# 198/290 진행중...
# 199/290 진행중...
# 200/290 진행중...
# 201/290 진행중...
# 202/290 진행중...
# 203/290 진행중...
# 204/290 진행중...
# 205/290 진행중...
# 206/290 진행중...
# 207/290 진행중...
# 208/290 진행중...
# 209/290 진행중...
# 210/290 진행중...
# 211/290 진행중...
# 212/290 진행중...
# 213/290 진행중...
# 214/290 진행중...
# 215/290 진행중...
# 216/290 진행중...
# 217/290 진행중...
# 218/290 진행중...
# 219/290 진행중...
# 220/290 진행중...
# 221/290 진행중...
# 222/290 진행중...
# 223/290 진행중...
# 224/290 진행중...
# 225/290 진행중...
# 226/290 진행중...
# 227/290 진행중...
# 228/290 진행중...
# 229/290 진행중...
# 230/290 진행중...
# 231/290 진행중...
# 232/290 진행중...
# 233/290 진행중...
# 234/290 진행중...
# 235/290 진행중...
# 236/290 진행중...
# 237/290 진행중...
# 238/290 진행중...
# 239/290 진행중...
# 240/290 진행중...
# 241/290 진행중...
# 242/290 진행중...
# 243/290 진행중...
# 244/290 진행중...
# 245/290 진행중...
# 246/290 진행중...
# 247/290 진행중...
# 248/290 진행중...
# 249/290 진행중...
# 250/290 진행중...
# 251/290 진행중...
# 252/290 진행중...
# 253/290 진행중...
# 254/290 진행중...
# 255/290 진행중...
# 256/290 진행중...
# 257/290 진행중...
# 258/290 진행중...
# 259/290 진행중...
# 260/290 진행중...
# 261/290 진행중...
# 262/290 진행중...
# 263/290 진행중...
# 264/290 진행중...
# 265/290 진행중...
# 266/290 진행중...
# 267/290 진행중...
# 268/290 진행중...
# 269/290 진행중...
# 270/290 진행중...
# 271/290 진행중...
# 272/290 진행중...
# 273/290 진행중...
# 274/290 진행중...
# 275/290 진행중...
# 276/290 진행중...
# 277/290 진행중...
# 278/290 진행중...
# 279/290 진행중...
# 280/290 진행중...
# 281/290 진행중...
# 282/290 진행중...
# 283/290 진행중...
# 284/290 진행중...
# 285/290 진행중...
# 286/290 진행중...
# 287/290 진행중...
# 288/290 진행중...
# 289/290 진행중...
# [['연번',
#   '역번호',
#   '호선',
#   '역명',
#   '역전화번호',
#   '도로명주소',
#   '지번주소',
#   '127.14834880144522',
#   '37.528334424738375'],
#  ['1',
#   '150',
#   '1',
#   '서울',
#   '02-6110-1331',
#   '서울특별시 중구 세종대로 지하2(남대문로 5가)',
#   '서울특별시 중구 남대문로5가 73-6 서울역(1호선)',
#   '126.978346780',
#   '37.566700969'],
#  ['2',
#   '151',
#   '1',
#   '시청',
#   '02-6110-1321',
#   '서울특별시 중구 세종대로 지하101(정동)',
#   '서울특별시 중구 정동 5-5 시청역(1호선)',
#   '127.022379505',
#   '37.573411520'],
#  ['3',
#   '152',
#   '1',
#   '종각',
#   '02-6110-1311',
#   '서울특별시 종로구 종로 지하55(종로1가)',
#   '서울특별시 종로구 종로1가 54 종각역(1호선)',
#   '127.022379505',
#   '37.573411520'],
#  ['4',
#   '153',
#   '1',
#   '종로3가',
#   '02-6110-1301',
#   '서울특별시 종로구 종로 지하129(종로3가)',
#   '서울특별시 종로구 종로3가 10-5 종로3가역(1호선)',
#   '127.022379505',
#   '37.573411520'],
#  ['5',
#   '154',
#   '1',
#   '종로5가',
#   '02-6110-1291',
#   '서울특별시 종로구 종로 지하216(종로5가)',
#   '서울특별시 종로구 종로5가 82-1 종로5가역(1호선)',
#   '127.022379505',
#   '37.573411520'],
#  ['6',
#   '155',
#   '1',
#   '동대문',
#   '02-6110-1281',
#   '서울특별시 종로구 종로 지하302(창신동)',
#   '서울특별시 종로구 창신동 492-1 동대문역(1호선)',
#   '127.025093705',
#   '37.574718822'],
#  ['7',
#   '156',
#   '1',
#   '신설동',
#   '02-6110-1261',
#   '서울특별시 동대문구 왕산로 지하1(신설동)',
#   '서울특별시 동대문구 신설동 76-5 신설동역(1호선)',
#   '127.026716062',
#   '37.576899695'],
#  ['8',
#   '157',
#   '1',
#   '제기동',
#   '02-6110-1251',
#   '서울특별시 동대문구 왕산로 지하93(제기동)',
#   '서울특별시 동대문구 제기동 65 제기동역(1호선)',
#   '127.026716062',
#   '37.576899695'],
#  ['9',
#   '158',
#   '1',
#   '청량리(서울시립대입구)',
#   '02-6110-1241',
#   '서울특별시 동대문구 왕산로 지하205(전농동)',
#   '서울특별시 동대문구 전농동 620-69 청량리역(1호선)',
#   '127.017046549',
#   '37.573421235'],
#  ['10',
#   '159',
#   '1',
#   '동묘앞',
#   '02-6110-1271',
#   '서울특별시 종로구 종로 359(숭인동)',
#   '서울특별시 종로구 숭인동 117 동묘앞역(1호선)',
#   '126.963137882',
#   '37.558986276'],
#  ['11',
#   '201',
#   '2',
#   '시청',
#   '02-6110-2011',
#   '서울특별시 중구 서소문로 지하127(서소문동)',
#   '서울특별시 중구 서소문동 90-1 시청역(2호선)',
#   '126.980410427',
#   '37.566317667'],
#  ['12',
#   '202',
#   '2',
#   '을지로입구',
#   '02-6110-2021',
#   '서울특별시 중구 을지로 지하42(을지로1가)',
#   '서울특별시 중구 을지로1가 100-1 을지로입구역(2호선)',
#   '126.980410427',
#   '37.566317667'],
#  ['13',
#   '203',
#   '2',
#   '을지로3가',
#   '02-6110-2031',
#   '서울특별시 중구 을지로 지하106(을지로3가)',
#   '서울특별시 중구 을지로3가 347-3 을지로3가역(2호선)',
#   '126.980410427',
#   '37.566317667'],
#  ['14',
#   '204',
#   '2',
#   '을지로4가',
#   '02-6110-2041',
#   '서울특별시 중구 을지로 지하178(을지로4가)',
#   '서울특별시 중구 을지로4가 267-1 을지로4가역(2호선)',
#   '126.980410427',
#   '37.566317667'],
#  ['15',
#   '205',
#   '2',
#   '동대문역사문화공원(DDP)',
#   '02-6110-2051',
#   '서울특별시 중구 을지로 지하279(을지로7가)',
#   '서울특별시 중구 을지로 7가 112-3 동대문역사문화공원역(2호선)',
#   '126.985369719',
#   '37.560857778'],
#  ['16',
#   '206',
#   '2',
#   '신당',
#   '02-6110-2061',
#   '서울특별시 중구 퇴계로 지하431-1(신당동)',
#   '서울특별시 중구 신당동 99 신당역(2호선)',
#   '127.043583580',
#   '37.555586600'],
#  ['17',
#   '207',
#   '2',
#   '상왕십리',
#   '02-6110-2071',
#   '서울특별시 성동구 왕십리로 지하374(하왕십리동)',
#   '서울특별시 성동구 하왕십리동 946-14 상왕십리역(2호선)',
#   '127.043583580',
#   '37.555586600'],
#  ['18',
#   '208',
#   '2',
#   '왕십리(성동구청)',
#   '02-6110-2081',
#   '서울특별시 성동구 왕십리로 지하300(행당동)',
#   '서울특별시 성동구 행당동 192 왕십리역(2호선)',
#   '127.043583580',
#   '37.555586600'],
#  ['19',
#   '209',
#   '2',
#   '한양대',
#   '02-6110-2091',
#   '서울특별시 성동구 왕십리로 206(행당동)',
#   '서울특별시 성동구 행당동 산17 한양대역(2호선)',
#   '127.047353428',
#   '37.547192441'],
#  ['20',
#   '210',
#   '2',
#   '뚝섬',
#   '02-6110-2101',
#   '서울특별시 성동구 아차산로 18(성수동1가)',
#   '서울특별시 성동구 성수동1가 656-745 뚝섬역(2호선)',
#   '127.056081489',
#   '37.544505657'],
#  ['21',
#   '211',
#   '2',
#   '성수',
#   '02-6110-2111',
#   '서울특별시 성동구 아차산로 100(성수동2가)',
#   '서울특별시 성동구 성수동2가 300-1 성수역(2호선)',
#   '127.069163804',
#   '37.540422470'],
#  ['22',
#   '212',
#   '2',
#   '건대입구',
#   '02-6110-2121',
#   '서울특별시 광진구 아차산로 243(화양동)',
#   '서울특별시 광진구 화양동 7-3 2호선 건대입구역(2호선)',
#   '127.086169250',
#   '37.537150616'],
#  ['23',
#   '213',
#   '2',
#   '구의(광진구청)',
#   '02-6110-2131',
#   '서울특별시 광진구 아차산로 384-1(구의동)',
#   '서울특별시 광진구 구의동 245-24 구의역(2호선)',
#   '127.094666351',
#   '37.535166584'],
#  ['24',
#   '214',
#   '2',
#   '강변(동서울터미널)',
#   '02-6110-2141',
#   '서울특별시 광진구 강변역로 53(구의동)',
#   '서울특별시 광진구 구의동 546-6 강변역(2호선)',
#   '127.103817729',
#   '37.520673932'],
#  ['25',
#   '215',
#   '2',
#   '잠실나루',
#   '02-6110-2151',
#   '서울특별시 송파구 오금로 20(신천동)',
#   '서울특별시 송파구 신천동 15 잠실나루역(2호선)',
#   '127.088639420',
#   '37.516280673'],
#  ['26',
#   '216',
#   '2',
#   '잠실(송파구청)',
#   '02-6110-2161',
#   '서울특별시 송파구 올림픽로 지하265(신천동)',
#   '서울특별시 송파구 신천동 8 잠실역(2호선)',
#   '127.086375269',
#   '37.511591761'],
#  ['27',
#   '217',
#   '2',
#   '잠실새내',
#   '02-6110-2171',
#   '서울특별시 송파구 올림픽로 지하140(잠실동)',
#   '서울특별시 송파구 잠실동 33 잠실새내역(2호선)',
#   '127.086375269',
#   '37.511591761'],
#  ['28',
#   '218',
#   '2',
#   '종합운동장',
#   '02-6110-2181',
#   '서울특별시 송파구 올림픽로 지하23(잠실동)',
#   '서울특별시 송파구 잠실동 122 종합운동장역(2호선)',
#   '127.035677325',
#   '37.500848849'],
#  ['29',
#   '219',
#   '2',
#   '삼성(무역센터)',
#   '02-6110-2191',
#   '서울특별시 강남구 테헤란로 지하538(삼성동)',
#   '서울특별시 강남구 삼성동 172-66 삼성역(2호선)',
#   '127.035677325',
#   '37.500848849'],
#  ['30',
#   '220',
#   '2',
#   '선릉',
#   '02-6110-2201',
#   '서울특별시 강남구 테헤란로 지하340(삼성동)',
#   '서울특별시 강남구 삼성동 172-66 선릉역(2호선)',
#   '127.035677325',
#   '37.500848849'],
#  ['31',
#   '221',
#   '2',
#   '역삼',
#   '02-6110-2211',
#   '서울특별시 강남구 테헤란로 지하156(역삼동)',
#   '서울특별시 강남구 역삼동 804 역삼역(2호선)',
#   '127.025732788',
#   '37.510747047'],
#  ['32',
#   '222',
#   '2',
#   '강남',
#   '02-6110-2221',
#   '서울특별시 강남구 강남대로 지하396(역삼동)',
#   '서울특별시 강남구 역삼동 858 강남역(2호선)',
#   '127.03826825217584',
#   '37.50124661553012'],
#  ['33',
#   '223',
#   '2',
#   '"교대(법원',
#   ' 검찰청)"',
#   '02-6110-2231',
#   '서울특별시 서초구 서초대로 지하294(서초동)',
#   '서울특별시 서초구 서초동 1748-4 교대역(2호선)',
#   '126.993190752',
#   '37.487885181'],
#  ['34',
#   '224',
#   '2',
#   '서초',
#   '02-6110-2241',
#   '서울특별시 서초구 서초대로 지하233(서초동)',
#   '서울특별시 서초구 서초동 1748-5 서초역(2호선)',
#   '126.992301766',
#   '37.489009745'],
#  ['35',
#   '225',
#   '2',
#   '방배',
#   '02-6110-2251',
#   '서울특별시 서초구 방배로 지하80(방배동)',
#   '서울특별시 서초구 방배동 912-14 방배역(2호선)',
#   '126.971282840',
#   '37.475818575'],
#  ['36',
#   '226',
#   '2',
#   '사당',
#   '02-6110-2261',
#   '서울특별시 동작구 남부순환로 지하2089(사당동)',
#   '서울특별시 동작구 사당동 1129 사당역(2호선)',
#   '126.956731112',
#   '37.477552074'],
#  ['37',
#   '227',
#   '2',
#   '낙성대(강감찬)',
#   '02-6110-2271',
#   '서울특별시 관악구 남부순환로 지하1928(봉천동)',
#   '서울특별시 관악구 봉천동 1693-39 낙성대역(2호선)',
#   '126.956731112',
#   '37.477552074'],
#  ['38',
#   '228',
#   '2',
#   '서울대입구(관악구청)',
#   '02-6110-2281',
#   '서울특별시 관악구 남부순환로 지하1822(봉천동)',
#   '서울특별시 관악구 봉천동 979-2 서울대입구역(2호선)',
#   '126.923485196',
#   '37.479616605'],
#  ['39',
#   '229',
#   '2',
#   '봉천',
#   '02-6110-2291',
#   '서울특별시 관악구 남부순환로 지하1721(봉천동)',
#   '서울툭별시 관악구 봉천동 979-7 봉천역(2호선)',
#   '126.960690293',
#   '37.477864522'],
#  ['40',
#   '230',
#   '2',
#   '신림',
#   '02-6110-2301',
#   '서울특별시 관악구 남부순환로 지하1614(신림동)',
#   '서울특별시 관악구 신림동 1467-10 신림역(2호선)',
#   '126.913172112',
#   '37.487573540'],
#  ['41',
#   '231',
#   '2',
#   '신대방',
#   '02-6110-2311',
#   '서울특별시 동작구 대림로 2(신대방동)',
#   '서울특별시 동작구 신대방동 643-1 신대방역(2호선)',
#   '126.901172551',
#   '37.485397433'],
#  ['42',
#   '232',
#   '2',
#   '구로디지털단지',
#   '02-6110-2321',
#   '서울특별시 구로구 도림천로 477(구로동)',
#   '서울특별시 구로구 구로동 810-3 구로디지털단지역(2호선)',
#   '126.894953627',
#   '37.493327112'],
#  ['43',
#   '233',
#   '2',
#   '대림(구로구청)',
#   '02-6110-2331',
#   '서울특별시 구로구 도림천로 351(구로동)',
#   '서울특별시 구로구 구로동 1204 대림역(2호선)',
#   '126.885341847',
#   '37.503305730'],
#  ['44',
#   '234',
#   '2',
#   '신도림',
#   '02-6110-2341',
#   '서울특별시 구로구 새말로 지하 117-21(신도림동)',
#   '서울특별시 구로구 신도림동 460-26 신도림역(2호선)',
#   '126.894855420',
#   '37.516869343'],
#  ['45',
#   '235',
#   '2',
#   '문래',
#   '02-6110-2351',
#   '서울특별시 영등포구 당산로 지하28(문래동3가)',
#   '서울특별시 영등포구 문래동3가 68-1 문래역(2호선)',
#   '126.901997727',
#   '37.534559592'],
#  ['46',
#   '236',
#   '2',
#   '영등포구청',
#   '02-6110-2361',
#   '서울특별시 영등포구 당산로 지하121(당산동3가)',
#   '서울특별시 영등포구 당산동3가 270-1 영등포구청역(2호선)',
#   '126.902946395',
#   '37.535244209'],
#  ['47',
#   '237',
#   '2',
#   '당산',
#   '02-6110-2371',
#   '서울특별시 영등포구 당산로 229(당산동6가)',
#   '서울특별시 영등포구 당산동 6가 323-1 당산역(2호선)',
#   '126.918706804',
#   '37.552699027'],
#  ['48',
#   '238',
#   '2',
#   '합정',
#   '02-6110-2381',
#   '서울특별시 마포구 양화로 지하55(서교동)',
#   '서울특별시 마포구 서교동 393 합정역(2호선)',
#   '126.918706804',
#   '37.552699027'],
#  ['49',
#   '239',
#   '2',
#   '홍대입구',
#   '02-6110-2391',
#   '서울특별시 마포구 양화로 지하160(동교동)',
#   '서울특별시 마포구 동교동 165 홍대입구역(2호선)',
#   '126.927338172',
#   '37.558248776'],
#  ['50',
#   '240',
#   '2',
#   '신촌(지하)',
#   '02-6110-2401',
#   '서울특별시 마포구 신촌로 지하90(노고산동)',
#   '서울특별시 마포구 노고산동 31-11 신촌역(2호선)',
#   '126.927338172',
#   '37.558248776'],
#  ['51',
#   '241',
#   '2',
#   '이대',
#   '02-6110-2411',
#   '서울특별시 마포구 신촌로 지하180(염리동)',
#   '서울특별시 마포구 염리동 8-85 이대역(2호선)',
#   '126.927338172',
#   '37.558248776'],
#  ['52',
#   '242',
#   '2',
#   '아현',
#   '02-6110-2421',
#   '서울특별시 마포구 신촌로 지하270(아현동)',
#   '서울특별시 마포구 아현동 354-23 아현역(2호선)',
#   '126.965604887',
#   '37.560802486'],
#  ['53',
#   '243',
#   '2',
#   '충정로(경기대입구)',
#   '02-6110-2431',
#   '서울특별시 서대문구 서소문로 지하17(충정로3가)',
#   '서울특별시 서대문구 충정로3가 319-1 충정로역(2호선)',
#   '127.050731660',
#   '37.562000011'],
#  ['54',
#   '244',
#   '2',
#   '용답',
#   '02-6110-1341',
#   '서울특별시 성동구 용답길 86(용답동)',
#   '서울특별시 성동구 용답동 127 용답역(2호선)',
#   '127.046785293',
#   '37.570038503'],
#  ['55',
#   '245',
#   '2',
#   '신답',
#   '02-6110-1351',
#   '서울특별시 성동구 천호대로 232(용답동)',
#   '서울특별시 성동구 용답동 129-2 신답역(2호선)',
#   '127.025093705',
#   '37.574718822'],
#  ['56',
#   '246',
#   '2',
#   '신설동',
#   '02-6110-1371',
#   '서울특별시 동대문구 왕산로 지하 1(신설동)',
#   '서울특별시 동대문구 신설동 76-5 신설동역(2호선)',
#   '126.882698119',
#   '37.514438646'],
#  ['57',
#   '247',
#   '2',
#   '도림천',
#   '02-6110-2441',
#   '서울특별시 구로구 경인로67길 160(신도림동)',
#   '서울특별시 구로구 신도림동 323-16 도림천역(2호선)',
#   '126.858612256',
#   '37.510483611'],
#  ['58',
#   '248',
#   '2',
#   '양천구청',
#   '02-6110-2451',
#   '서울특별시 양천구 목동로3길 지하33(신정동)',
#   '서울특별시 양천구 신정동 276-7 양천구청역(2호선)',
#   '126.854790905',
#   '37.515151298'],
#  ['59',
#   '249',
#   '2',
#   '신정네거리',
#   '02-6110-2461',
#   '서울특별시 양천구 중앙로 지하261(신정동)',
#   '서울특별시 양천구 신정동 1231 신정네거리역(2호선)',
#   '127.039962351',
#   '37.574358519'],
#  ['60',
#   '250',
#   '2',
#   '용두(동대문구청)',
#   '02-6110-1361',
#   '서울특별시 동대문구 천호대로 지하129(용두동)',
#   '서울특별시 동대문구 용두동 47-1 용두역(2호선)',
#   '126.902956457',
#   '37.653094172'],
#  ['61',
#   '309',
#   '3',
#   '지축',
#   '02-6110-3191',
#   '경기도 고양시 덕양구 삼송로 300(지축동)',
#   '경기도 고양시 덕양구 지축동 818-64 지축역(3호선)',
#   '126.920735906',
#   '37.634963223'],
#  ['62',
#   '310',
#   '3',
#   '구파발',
#   '02-6110-3201',
#   '서울특별시 은평구 진관2로 지하15-25 (진관동)',
#   '서울특별시 은평구 진관동 67-26 구파발역(3호선)',
#   '126.936154165',
#   '37.600767190'],
#  ['63',
#   '311',
#   '3',
#   '연신내',
#   '02-6110-3211',
#   '서울특별시 은평구 통일로 지하849(갈현동)',
#   '서울특별시 은평구 갈현동 397 연신내역(3호선)',
#   '126.929857627',
#   '37.610136633'],
#  ['64',
#   '312',
#   '3',
#   '불광',
#   '02-6110-3221',
#   '서울특별시 은평구 통일로 지하723-1(대조동)',
#   '서울특별시 은평구 대조동 13-10 불광역(3호선)',
#   '126.929857627',
#   '37.610136633'],
#  ['65',
#   '313',
#   '3',
#   '녹번',
#   '02-6110-3231',
#   '서울특별시 은평구 통일로 지하602-1(녹번동)',
#   '서울특별시 은평구 녹번동 55 녹번역(3호선)',
#   '126.944882582',
#   '37.587697084'],
#  ['66',
#   '314',
#   '3',
#   '홍제',
#   '02-6110-3241',
#   '서울특별시 서대문구 통일로 지하440-1(홍제동)',
#   '서울특별시 서대문구 홍제동 161-1 홍제역(3호선)',
#   '126.944882582',
#   '37.587697084'],
#  ['67',
#   '315',
#   '3',
#   '무악재',
#   '02-6110-3251',
#   '서울특별시 서대문구 통일로 지하361(홍제동)',
#   '서울특별시 서대문구 홍제동 26-1 무악재역(3호선)',
#   '126.946464954',
#   '37.586173232'],
#  ['68',
#   '316',
#   '3',
#   '독립문',
#   '02-6110-3261',
#   '서울특별시 서대문구 통일로 지하247(현저동)',
#   '서울특별시 서대문구 현저동 101 독립문역(3호선)',
#   '126.969984681',
#   '37.576307929'],
#  ['69',
#   '317',
#   '3',
#   '경복궁(정부서울청사)',
#   '02-6110-3271',
#   '서울특별시 종로구 사직로 지하130(적선동)',
#   '서울특별시 종로구 적선동 81-1 경복궁역(3호선)',
#   '127.009570564',
#   '37.570323758'],
#  ['70',
#   '318',
#   '3',
#   '안국',
#   '02-6110-3281',
#   '서울특별시 종로구 율곡로 지하62(안국동)',
#   '서울특별시 종로구 안국동 73-1 안국역(3호선)',
#   '126.991795616',
#   '37.570986945'],
#  ['71',
#   '319',
#   '3',
#   '종로3가',
#   '02-6110-3291',
#   '서울특별시 종로구 돈화문로 지하30(묘동)',
#   '서울특별시 종로구 묘동 20-5 종로3가역(3호선)',
#   '126.980410427',
#   '37.566317667'],
#  ['72',
#   '320',
#   '3',
#   '을지로3가',
#   '02-6110-3301',
#   '서울특별시 중구 을지로 지하129(을지로3가)',
#   '서울특별시 중구 을지로3가 282-8 을지로3가역(3호선)',
#   '126.985369719',
#   '37.560857778'],
#  ['73',
#   '321',
#   '3',
#   '충무로',
#   '02-6110-4231',
#   '서울특별시 중구 퇴계로 지하214(필동2가)',
#   '서울특별시 중구 필동2가 16-2 충무로역(3호선)',
#   '127.002091083',
#   '37.568965945'],
#  ['74',
#   '322',
#   '3',
#   '동대입구',
#   '02-6110-3321',
#   '서울특별시 중구 동호로 지하256(장충동2가)',
#   '서울특별시 중구 장충동2가 199-3 동대입구역(3호선)',
#   '127.010875982',
#   '37.562360401'],
#  ['75',
#   '323',
#   '3',
#   '약수',
#   '02-6110-3331',
#   '서울특별시 중구 다산로 지하122(신당동)',
#   '서울특별시 중구 신당동 369-44 약수역(3호선)',
#   '127.016940574',
#   '37.549546367'],
#  ['76',
#   '324',
#   '3',
#   '금호',
#   '02-6110-3341',
#   '서울특별시 성동구 동호로 지하104(금호동4가)',
#   '서울특별시 성동구 금호동4가 1470 금호역(3호선)',
#   '127.018965389',
#   '37.540987725'],
#  ['77',
#   '325',
#   '3',
#   '옥수',
#   '02-6110-3351',
#   '서울특별시 성동구 동호로 21(옥수동)',
#   '서울특별시 성동구 옥수동 168-1 옥수역(3호선)',
#   '127.023760126',
#   '37.529326042'],
#  ['78',
#   '326',
#   '3',
#   '압구정',
#   '02-6110-3361',
#   '서울특별시 강남구 압구정로 지하172(신사동)',
#   '서울특별시 강남구 신사동 668 압구정역(3호선)',
#   '127.053148282',
#   '37.526682150'],
#  ['79',
#   '327',
#   '3',
#   '신사',
#   '02-6110-3371',
#   '서울특별시 강남구 도산대로 지하102(신사동)',
#   '서울특별시 강남구 신사동 667 신사역(3호선)',
#   '127.010648272',
#   '37.512809973'],
#  ['80',
#   '328',
#   '3',
#   '잠원',
#   '02-6110-3381',
#   '서울특별시 서초구 잠원로4길 지하46(잠원동)',
#   '서울특별시 서초구 잠원동 100-1 잠원역(3호선)',
#   '127.013355196',
#   '37.507879138'],
#  ['81',
#   '329',
#   '3',
#   '고속터미널',
#   '02-6110-3391',
#   '서울특별시 서초구 신반포로 지하188(반포동)',
#   '서울특별시 서초구 반포동 19-11 고속터미널역(3호선)',
#   '127.01174548067499',
#   '37.51306289209155'],
#  ['82',
#   '330',
#   '3',
#   '"교대(법원',
#   ' 검찰청)"',
#   '02-6110-3401',
#   '서울특별시 서초구 서초대로 지하294(서초동)',
#   '서울특별시 서초구 서초동 1748-4 교대역(3호선)',
#   '127.014858582',
#   '37.494441511'],
#  ['83',
#   '331',
#   '3',
#   '남부터미널(예술의전당)',
#   '02-6110-3411',
#   '서울특별시 서초구 서초중앙로 지하31(서초동)',
#   '서울특별시 서초구 서초동 1748-30 남부터미널역(3호선)',
#   '127.032595021',
#   '37.483596826'],
#  ['84',
#   '332',
#   '3',
#   '양재(서초구청)',
#   '02-6110-3421',
#   '서울특별시 서초구 남부순환로 지하2585(서초동)',
#   '서울특별시 서초구 서초동 1366-9 양재역(3호선)',
#   '127.035096535',
#   '37.484963731'],
#  ['85',
#   '333',
#   '3',
#   '매봉',
#   '02-6110-3431',
#   '서울특별시 강남구 남부순환로 지하2744(도곡동)',
#   '서울특별시 강남구 도곡동 179-2 매봉역(3호선)',
#   '127.045608837',
#   '37.487927938'],
#  ['86',
#   '334',
#   '3',
#   '도곡',
#   '02-6110-3441',
#   '서울특별시 강남구 남부순환로 지하2814(도곡동)',
#   '서울특별시 강남구 도곡동 339-2 도곡역(3호선)',
#   '127.034740390',
#   '37.485495175'],
#  ['87',
#   '335',
#   '3',
#   '대치',
#   '02-6110-3451',
#   '서울특별시 강남구 남부순환로 지하2952(대치동)',
#   '서울특별시 강남구 대치동 317-3 대치역(3호선)',
#   '127.034740390',
#   '37.485495175'],
#  ['88',
#   '336',
#   '3',
#   '학여울',
#   '02-6110-3461',
#   '서울특별시 강남구 남부순환로 지하3104(대치동)',
#   '서울특별시 강남구 대치동 514-3 학여울역(3호선)',
#   '127.084152093',
#   '37.492197944'],
#  ['89',
#   '337',
#   '3',
#   '대청',
#   '02-6110-3471',
#   '서울특별시 강남구 일원로 지하2(일원동)',
#   '서울특별시 강남구 일원동 700-9 대청역(3호선)',
#   '127.086325960',
#   '37.482199390'],
#  ['90',
#   '338',
#   '3',
#   '일원',
#   '02-6110-3481',
#   '서울특별시 강남구 일원로 지하121(일원동)',
#   '서울특별시 강남구 일원동 717 일원역(3호선)',
#   '127.097719081',
#   '37.486710903'],
#  ['91',
#   '339',
#   '3',
#   '수서',
#   '02-6110-3491',
#   '서울특별시 강남구 광평로 지하270(수서동)',
#   '서울특별시 강남구 수서동 728 수서역(3호선)',
#   '127.096078784',
#   '37.516719214'],
#  ['92',
#   '340',
#   '3',
#   '가락시장',
#   '02-6110-3501',
#   '서울특별시 송파구 송파대로 지하257(가락동)',
#   '서울특별시 송파구 가락동 184-23 가락시장역(3호선)',
#   '127.132977691',
#   '37.507064735'],
#  ['93',
#   '341',
#   '3',
#   '경찰병원',
#   '02-6110-3511',
#   '서울특별시 송파구 중대로 지하149(가락동)',
#   '서울특별시 송파구 가락동 10-15 경찰병원역(3호선)',
#   '127.126225701',
#   '37.504492286'],
#  ['94',
#   '342',
#   '3',
#   '오금',
#   '02-6110-3521',
#   '서울특별시 송파구 오금로 지하321(오금동)',
#   '서울특별시 송파구 오금동 44-2 오금역(3호선)',
#   '127.078858505',
#   '37.670158431'],
#  ['95',
#   '409',
#   '4',
#   '불암산',
#   '02-6110-4091',
#   '서울특별시 노원구 상계로 305(상계동)',
#   '서울특별시 노원구 상계동 111 불암산역(4호선)',
#   '127.073641730',
#   '37.660976439'],
#  ['96',
#   '410',
#   '4',
#   '상계',
#   '02-6110-4101',
#   '서울특별시 노원구 상계로 182(상계동)',
#   '서울특별시 노원구 상계동 156-203 상계역(4호선)',
#   '127.063028584',
#   '37.656267243'],
#  ['97',
#   '411',
#   '4',
#   '노원',
#   '02-6110-4111',
#   '서울특별시 노원구 상계로 69-1(상계동)',
#   '서울특별시 노원구 상계동 602-5 노원역(4호선)',
#   '127.047683782',
#   '37.653208466'],
#  ['98',
#   '412',
#   '4',
#   '창동',
#   '02-6110-4121',
#   '서울특별시 도봉구 마들로11길 77(창동)',
#   '서울특별시 도봉구 창동 135-1 창동역(4호선)',
#   '127.039661274',
#   '37.656555835'],
#  ['99',
#   '413',
#   '4',
#   '쌍문',
#   '02-6110-4131',
#   '서울특별시 도봉구 도봉로 지하 486-1(창동)',
#   '서울특별시 도봉구 창동 703-4 쌍문역(4호선)',
#   '127.023281584',
#   '37.636930453'],
#  ['100',
#   '414',
#   '4',
#   '수유(강북구청)',
#   '02-6110-4141',
#   '서울특별시 강북구 도봉로 지하338(수유동)',
#   '서울특별시 강북구 수유동 140 수유역(4호선)',
#   '127.028294603',
#   '37.620021979'],
#  ['101',
#   '415',
#   '4',
#   '미아(서울사이버대학)',
#   '02-6110-4151',
#   '서울특별시 강북구 도봉로 지하198(미아동)',
#   '서울특별시 강북구 미아동 194-1 미아역(4호선)',
#   '127.024932838',
#   '37.633615091'],
#  ['102',
#   '416',
#   '4',
#   '미아사거리 ',
#   '02-6110-4161',
#   '서울특별시 강북구 도봉로 지하50(미아동)',
#   '서울특별시 강북구 미아동 66-1 미아사거리역(4호선)',
#   '127.006332800',
#   '37.588802708'],
#  ['103',
#   '417',
#   '4',
#   '길음',
#   '02-6110-4171',
#   '서울특별시 성북구 동소문로 지하248(길음동)',
#   '서울특별시 성북구 길음동 877-66 길음역(4호선)',
#   '127.023666407',
#   '37.602961355'],
#  ['104',
#   '418',
#   '4',
#   '성신여대입구(돈암)',
#   '02-6110-4181',
#   '서울특별시 성북구 동소문로 지하102(동선동4가)',
#   '서울특별시 성북구 동선동4가 1 성신여대입구역(4호선)',
#   '127.013760202',
#   '37.589250602'],
#  ['105',
#   '419',
#   '4',
#   '한성대입구(삼선교)',
#   '02-6110-4191',
#   '서울특별시 성북구 삼선교로 지하1(삼선동1가)',
#   '서울특별시 성북구 삼선동1가 14 한성대입구역(4호선)',
#   '127.001324724',
#   '37.583098433'],
#  ['106',
#   '420',
#   '4',
#   '혜화',
#   '02-6110-4201',
#   '서울특별시 종로구 대학로 지하120(명륜4가)',
#   '서울특별시 종로구 명륜4가 96-5 혜화역(4호선)',
#   '127.005828778',
#   '37.574472466'],
#  ['107',
#   '421',
#   '4',
#   '동대문',
#   '02-6110-4211',
#   '서울특별시 종로구 율곡로 지하308(종로6가)',
#   '서울특별시 종로구 종로6가 287-1 동대문역(4호선)',
#   '127.009680766',
#   '37.569196642'],
#  ['108',
#   '422',
#   '4',
#   '동대문역사문화공원(DDP)',
#   '02-6110-4221',
#   '서울특별시 중구 장충단로 지하230(광희동2가)',
#   '서울특별시 중구 광희동2가 9 동대문역사문화공원역(4호선)',
#   '126.985369719',
#   '37.560857778'],
#  ['109',
#   '423',
#   '4',
#   '충무로',
#   '02-6110-4231',
#   '서울특별시 중구 퇴계로 지하214(필동2가)',
#   '서울특별시 중구 필동2가 16-2 충무로역(4호선)',
#   '126.995024271',
#   '37.561932189'],
#  ['110',
#   '424',
#   '4',
#   '명동',
#   '02-6110-4241',
#   '서울특별시 중구 퇴계로 지하126(충무로2가)',
#   '서울특별시 중구 충무로2가 109-2 명동역(4호선)',
#   '126.985369719',
#   '37.560857778'],
#  ['111',
#   '425',
#   '4',
#   '회현(남대문시장)',
#   '02-6110-4251',
#   '서울특별시 중구 퇴계로 지하54(남창동)',
#   '서울특별시 중구 남창동 64-1 회현역(4호선)',
#   '126.970681601',
#   '37.531652708'],
#  ['112',
#   '426',
#   '4',
#   '서울',
#   '02-6110-4261',
#   '서울특별시 용산구 한강대로 지하392(동자동)',
#   '서울특별시 용산구 동자동 14-151 서울역 (4호선)',
#   '126.970681601',
#   '37.531652708'],
#  ['113',
#   '427',
#   '4',
#   '숙대입구(갈월)',
#   '02-6110-4271',
#   '서울특별시 용산구 한강대로 지하306(갈월동)',
#   '서울특별시 용산구 갈월동 16-7 숙대입구역(4호선)',
#   '126.969190977',
#   '37.530236013'],
#  ['114',
#   '428',
#   '4',
#   '삼각지(전쟁기념관)',
#   '02-6110-4281',
#   '서울특별시 용산구 한강대로 지하180(한강로1가)',
#   '서울특별시 용산구 한강로1가 228-1 삼각지역(4호선)',
#   '126.969190977',
#   '37.530236013'],
#  ['115',
#   '429',
#   '4',
#   '신용산',
#   '02-6110-4291',
#   '서울특별시 용산구 한강대로 지하112(한강로2가)',
#   '서울특별시 용산구 한강로2가 181 신용산역(4호선)',
#   '126.967336731',
#   '37.523707313'],
#  ['116',
#   '430',
#   '4',
#   '이촌(국립중앙박물관)',
#   '02-6110-4301',
#   '서울특별시 용산구 서빙고로 지하83(용산동5가)',
#   '서울특별시 용산구 용산동5가 17-112 이촌역(4호선)',
#   '126.980426330',
#   '37.502589384'],
#  ['117',
#   '431',
#   '4',
#   '동작(현충원)',
#   '02-6110-4311',
#   '서울특별시 동작구 현충로 257(동작동)',
#   '서울특별시 동작구 동작동 327-1 동작역(4호선)',
#   '126.978067764',
#   '37.495841336'],
#  ['118',
#   '432',
#   '4',
#   '총신대입구(이수)',
#   '02-6110-4321',
#   '서울특별시 동작구 동작대로 지하117(사당동)',
#   '서울특별시 동작구 사당동 736-1 총신대입구(이수)역(4호선)',
#   '126.980896858',
#   '37.492088374'],
#  ['119',
#   '433',
#   '4',
#   '사당',
#   '02-6110-4331',
#   '서울특별시 동작구  동작대로 지하3(사당동)',
#   '서울특별시 동작구 사당동 588-44 사당역(4호선)',
#   '126.988943111',
#   '37.464571626'],
#  ['120',
#   '434',
#   '4',
#   '남태령',
#   '02-6110-4341',
#   '서울특별시 서초구 과천대로 지하816(방배동)',
#   '서울특별시 서초구 방배동 2909 남태령역(4호선)',
#   '126.808400766',
#   '37.587601833'],
#  ['121',
#   '2511',
#   '5',
#   '방화',
#   '02-6311-5101',
#   '서울특별시 강서구 금낭화로 지하132(방화동)',
#   '서울특별시 강서구 방화동 829-15 방화역(5호선)',
#   '126.806111833',
#   '37.572250630'],
#  ['122',
#   '2512',
#   '5',
#   '개화산',
#   '02-6311-5111',
#   '서울특별시 강서구 양천로 22(방화동)',
#   '서울특별시 강서구 방화동 846 개화산역(5호선)',
#   '126.804607058',
#   '37.560514240'],
#  ['123',
#   '2513',
#   '5',
#   '김포공항',
#   '02-6311-5121',
#   '서울특별시 강서구 하늘길 지하77(방화동)',
#   '서울특별시 강서구 방화동 886 김포공항역(5호선)',
#   '126.819206246',
#   '37.562266973'],
#  ['124',
#   '2514',
#   '5',
#   '송정',
#   '02-6311-5131',
#   '서울특별시 강서구 공항대로 지하33(공항동)',
#   '서울특별시 강서구 공항동 29-5 송정역(5호선)',
#   '126.819206246',
#   '37.562266973'],
#  ['125',
#   '2515',
#   '5',
#   '마곡',
#   '02-6311-5141',
#   '서울특별시 강서구 공항대로 지하163(마곡동)',
#   '서울특별시 강서구 마곡동 769-3 마곡역(5호선)',
#   '126.819206246',
#   '37.562266973'],
#  ['126',
#   '2516',
#   '5',
#   '발산',
#   '02-6311-5151',
#   '서울특별시 강서구 공항대로 지하267(마곡동)',
#   '서울특별시 강서구 마곡동 727-1496 발산역(5호선)',
#   '126.837141647',
#   '37.541487646'],
#  ['127',
#   '2517',
#   '5',
#   '우장산',
#   '02-6311-5161',
#   '서울특별시 강서구 강서로 지하262(화곡동)',
#   '서울특별시 강서구 화곡동 1089-3 우장산역(5호선)',
#   '126.849496775',
#   '37.550908930'],
#  ['128',
#   '2518',
#   '5',
#   '화곡',
#   '02-6311-5171',
#   '서울특별시 강서구 화곡로 지하168(화곡동)',
#   '서울특별시 강서구 화곡동 1089-54 화곡역(5호선)',
#   '126.837141647',
#   '37.541487646'],
#  ['129',
#   '2519',
#   '5',
#   '까치산',
#   '02-6311-5181',
#   '서울특별시 강서구 강서로 지하54(화곡동)',
#   '서울특별시 강서구 화곡동 662-5 까치산역(5호선)',
#   '126.838984082',
#   '37.521144771'],
#  ['130',
#   '2520',
#   '5',
#   '신정(은행정)',
#   '02-6311-5191',
#   '서울특별시 양천구 오목로 지하179(신정동)',
#   '서울특별시 양천구 신정동 1090 신정역(5호선)',
#   '126.838984082',
#   '37.521144771'],
#  ['131',
#   '2521',
#   '5',
#   '목동',
#   '02-6311-5201',
#   '서울특별시 양천구 오목로 지하245(목동)',
#   '서울특별시 양천구 목동 926-3 목동역(5호선)',
#   '126.838984082',
#   '37.521144771'],
#  ['132',
#   '2522',
#   '5',
#   '오목교(목동운동장앞)',
#   '02-6311-5211',
#   '서울특별시 양천구 오목로 지하342(목동)',
#   '서울특별시 양천구 목동 406-30 오목교역(5호선)',
#   '126.887876159',
#   '37.525748411'],
#  ['133',
#   '2523',
#   '5',
#   '양평',
#   '02-6311-5221',
#   '서울특별시 영등포구 양산로 지하21(양평동2가)',
#   '서울특별시 영등포구 양평동2가 33-79 양평역(5호선)',
#   '126.898800097',
#   '37.523830818'],
#  ['134',
#   '2524',
#   '5',
#   '영등포구청',
#   '02-6311-5231',
#   '서울특별시 영등포구 양산로 지하116(당산동3가)',
#   '서울특별시 영등포구 당산동3가 556-1 영등포구청역(5호선)',
#   '126.905140679',
#   '37.522705011'],
#  ['135',
#   '2525',
#   '5',
#   '영등포시장',
#   '02-6311-5241',
#   '서울특별시 영등포구 양산로 지하200(영등포동5가)',
#   '서울특별시 영등포구 영등포동5가 62-1 영등포시장역(5호선)',
#   '126.914021935',
#   '37.517371474'],
#  ['136',
#   '2526',
#   '5',
#   '신길',
#   '02-6311-5251',
#   '서울특별시 영등포구 경인로114가길 지하9(영등포동1가)',
#   '서울특별시 영등포구 영등포동1가 35 신길역(5호선)',
#   '126.930097742',
#   '37.525198889'],
#  ['137',
#   '2527',
#   '5',
#   '여의도',
#   '02-6311-5261',
#   '서울특별시 영등포구 여의나루로 지하40(여의도동)',
#   '서울특별시 영등포구 여의도동 3 여의도역(5호선)',
#   '126.931989053',
#   '37.517475917'],
#  ['138',
#   '2528',
#   '5',
#   '여의나루',
#   '02-6311-5271',
#   '서울특별시 영등포구 여의동로 지하343(여의도동)',
#   '서울특별시 영등포구 여의도동 84-4 여의나루역(5호선)',
#   '126.947815113',
#   '37.542259804'],
#  ['139',
#   '2529',
#   '5',
#   '마포',
#   '02-6311-5281',
#   '서울특별시 마포구 마포대로 지하33(도화동)',
#   '서울특별시 마포구 도화동 160 마포역(5호선)',
#   '126.941863529',
#   '37.540090490'],
#  ['140',
#   '2530',
#   '5',
#   '공덕',
#   '02-6311-5291',
#   '서울특별시 마포구 마포대로 지하100(공덕동)',
#   '서울특별시 마포구 공덕동 423-29 공덕역(5호선)',
#   '126.954633979',
#   '37.553914408'],
#  ['141',
#   '2531',
#   '5',
#   '애오개',
#   '02-6311-5301',
#   '서울특별시 마포구 마포대로 지하210(아현동)',
#   '서울특별시 마포구 아현동 612 애오개역(5호선)',
#   '126.966110742',
#   '37.561727620'],
#  ['142',
#   '2532',
#   '5',
#   '충정로(경기대입구)',
#   '02-6311-5311',
#   '서울특별시 서대문구 충정로 지하 28-1(충정로3가)',
#   '서울특별시 서대문구 충정로3가 248-1 충정로역(5호선)',
#   '126.966603477',
#   '37.565821319'],
#  ['143',
#   '2533',
#   '5',
#   '서대문',
#   '02-6311-5321',
#   '서울특별시 종로구 통일로 지하126(평동)',
#   '서울특별시 종로구 평동 210 서대문역(5호선)',
#   '126.975959103',
#   '37.573426185'],
#  ['144',
#   '2534',
#   '5',
#   '광화문(세종문화회관)',
#   '02-6311-5331',
#   '서울특별시 종로구 세종대로 지하172(세종로)',
#   '서울특별시 종로구 세종로 1-68 5호선 광화문역(5호선)',
#   '126.990839671',
#   '37.572714780'],
#  ['145',
#   '2535',
#   '5',
#   '종로3가(탑골공원)',
#   '02-6311-5341',
#   '서울특별시 종로구 돈화문로11길 지하 26(돈의동)',
#   '서울특별시 종로구 돈의동 39-1 5호선 종로3가역(5호선)',
#   '126.997564683',
#   '37.563796112'],
#  ['146',
#   '2536',
#   '5',
#   '을지로4가',
#   '02-6311-5351',
#   '서울특별시 중구 창경궁로 지하51(주교동)',
#   '서울특별시 중구 주교동 191 을지로4가역(5호선)',
#   '127.005252768',
#   '37.564975148'],
#  ['147',
#   '2537',
#   '5',
#   '동대문역사문화공원(DDP)',
#   '02-6311-5361',
#   '서울특별시 중구 마른내로 지하162(광희동1가)',
#   '서울특별시 중구 광희동1가 235-6 동대문역사문화공원역(5호선)',
#   '127.011542754',
#   '37.561163479'],
#  ['148',
#   '2538',
#   '5',
#   '청구',
#   '02-6311-5371',
#   '서울특별시 중구 청구로 지하77(신당동)',
#   '서울특별시 중구 신당동 295-2 청구역(5호선)',
#   '127.025113350',
#   '37.547507436'],
#  ['149',
#   '2539',
#   '5',
#   '신금호',
#   '02-6311-5381',
#   '서울특별시 성동구 금호로 지하154(금호동2가)',
#   '서울특별시 성동구 금호동2가 223-1 신금호역(5호선)',
#   '127.029234466',
#   '37.557280484'],
#  ['150',
#   '2540',
#   '5',
#   '행당',
#   '02-6311-5391',
#   '서울특별시 성동구 행당로 지하89(행당동)',
#   '서울특별시 성동구 행당동 317-241 행당역(5호선)',
#   '127.043583580',
#   '37.555586600'],
#  ['151',
#   '2541',
#   '5',
#   '왕십리(성동구청)',
#   '02-6311-5401',
#   '서울특별시 성동구 왕십리로 지하300(행당동)',
#   '서울특별시 성동구 행당동 192 왕십리역(5호선)',
#   '127.043175269',
#   '37.566290255'],
#  ['152',
#   '2542',
#   '5',
#   '마장',
#   '02-6311-5411',
#   '서울특별시 성동구 마장로 지하296(마장동)',
#   '서울특별시 성동구 마장동 804 마장역(5호선)',
#   '127.046785293',
#   '37.570038503'],
#  ['153',
#   '2543',
#   '5',
#   '답십리',
#   '02-6311-5421',
#   '서울특별시 성동구 천호대로 지하300(용답동)',
#   '서울특별시 성동구 용답동 99 답십리역(5호선)',
#   '127.039962351',
#   '37.574358519'],
#  ['154',
#   '2544',
#   '5',
#   '장한평',
#   '02-6311-5431',
#   '서울특별시 동대문구 천호대로 지하405(장안동)',
#   '서울특별시 동대문구 장안동 472-3 장한평역(5호선)',
#   '127.074483029',
#   '37.559523160'],
#  ['155',
#   '2545',
#   '5',
#   '군자(능동)',
#   '02-6311-5441',
#   '서울특별시 광진구 천호대로 지하550(능동)',
#   '서울특별시 광진구 능동 275-5 군자(능동)역(5호선)',
#   '127.102255667',
#   '37.546451829'],
#  ['156',
#   '2546',
#   '5',
#   '아차산(어린이대공원후문)',
#   '02-6311-5451',
#   '서울특별시 광진구 천호대로 지하657(능동)',
#   '서울특별시 광진구 능동 256-16 5호선 아차산역(5호선)',
#   '127.064774273',
#   '37.542487027'],
#  ['157',
#   '2547',
#   '5',
#   '광나루(장신대)',
#   '02-6311-5461',
#   '서울특별시 광진구 아차산로 지하571(광장동)',
#   '서울특별시 광진구 광장동 237 광나루역(5호선)',
#   '127.124449131',
#   '37.538987633'],
#  ['158',
#   '2548',
#   '5',
#   '천호(풍납토성)',
#   '02-6311-5471',
#   '서울특별시 강동구 천호대로 지하997(천호동)',
#   '서울특별시 강동구 천호동 455 천호역(5호선)',
#   '127.139072088',
#   '37.533187399'],
#  ['159',
#   '2549',
#   '5',
#   '강동',
#   '02-6311-5481',
#   '서울특별시 강동구 천호대로 지하1097(천호동)',
#   '서울특별시 강동구 천호동 447 강동역(5호선)',
#   '127.133670001',
#   '37.522485912'],
#  ['160',
#   '2550',
#   '5',
#   '길동',
#   '02-6311-5491',
#   '서울특별시 강동구 양재대로 지하1480(길동)',
#   '서울특별시 강동구 길동 378 길동역(5호선)',
#   '127.133670001',
#   '37.522485912'],
#  ['161',
#   '2551',
#   '5',
#   '굽은다리(강동구민회관앞)',
#   '02-6311-5501',
#   '서울특별시 강동구 양재대로 지하1572(명일동)',
#   '서울특별시 강동구 명일동 345-12 굽은다리역(5호선)',
#   '127.146861048',
#   '37.543148222'],
#  ['162',
#   '2552',
#   '5',
#   '명일',
#   '02-6311-5511',
#   '서울특별시 강동구 양재대로 지하1632(명일동)',
#   '서울특별시 강동구 명일동 312 명일역(5호선)',
#   '127.140795699',
#   '37.555001470'],
#  ['163',
#   '2553',
#   '5',
#   '고덕',
#   '02-6311-5521',
#   '서울특별시 강동구 고덕로 지하253(고덕동)',
#   '서울특별시 강동구 고덕동 310 고덕역(5호선)',
#   '127.140795699',
#   '37.555001470'],
#  ['164',
#   '2554',
#   '5',
#   '상일동',
#   '02-6311-5531',
#   '서울특별시 강동구 고덕로 지하359(상일동)',
#   '서울특별시 강동구 상일동 148 상일동역(5호선)',
#   '127.133670001',
#   '37.522485912'],
#  ['165',
#   '2555',
#   '5',
#   '둔촌동',
#   '02-6311-5541',
#   '서울특별시 강동구 양재대로 지하1369(둔촌동)',
#   '서울특별시 강동구 둔촌동 416 둔촌동역(5호선)',
#   '127.134326509',
#   '37.515450096'],
#  ['166',
#   '2556',
#   '5',
#   '올림픽공원(한국체대)',
#   '02-6311-5551',
#   '서울특별시 송파구 양재대로 지하1233(방이동)',
#   '서울특별시 송파구 방이동 89-28 올림픽공원역(5호선)',
#   '127.113455646',
#   '37.496465829'],
#  ['167',
#   '2557',
#   '5',
#   '방이',
#   '02-6311-5561',
#   '서울특별시 송파구 양재대로 지하1127(방이동)',
#   '서울특별시 송파구 방이동 217-2 방이역(5호선)',
#   '127.126225701',
#   '37.504492286'],
#  ['168',
#   '2558',
#   '5',
#   '오금',
#   '02-6110-3521',
#   '서울특별시 송파구 오금로 지하321(오금동)',
#   '서울특별시 송파구 오금동 44-2 오금역(5호선)',
#   '127.126225701',
#   '37.504492286'],
#  ['169',
#   '2559',
#   '5',
#   '개롱',
#   '02-6311-5581',
#   '서울특별시 송파구 오금로 지하402(가락동)',
#   '서울특별시 송파구 가락동 165-2 개롱역(5호선)',
#   '127.126225701',
#   '37.504492286'],
#  ['170',
#   '2560',
#   '5',
#   '거여',
#   '02-6311-5591',
#   '서울특별시 송파구 오금로 지하499(거여동)',
#   '서울특별시 송파구 거여동 20-14 거여역(5호선)',
#   '127.152462385',
#   '37.494646181'],
#  ['171',
#   '2561',
#   '5',
#   '마천',
#   '02-6311-5601',
#   '서울특별시 송파구 마천로57길 지하7(마천동)',
#   '서울특별시 송파구 마천동 307-4 마천역(5호선)',
#   '127.140795699',
#   '37.555001470'],
#  ['172',
#   '2562',
#   '5',
#   '강일',
#   '02-6311-5611',
#   '서울특별시 강동구 고덕로 지하456(강일동)',
#   '서울특별시 강동구 상일동 산73 강일역(5호선)',
#   '127.194193349',
#   '37.565145930'],
#  ['173',
#   '2563',
#   '5',
#   '미사',
#   '02-6311-5621',
#   '경기도 하남시 미사강변동로 지하90(망월동)',
#   '경기도 하남시 망월동 1122 미사역(5호선)',
#   '127.204786086',
#   '37.552512410'],
#  ['174',
#   '2564',
#   '5',
#   '하남풍산',
#   '02-6311-5631',
#   '경기도 하남시 덕풍서로 지하50(덕풍동)',
#   '경기도 하남시 덕풍동 727-3 하남풍산역(5호선)',
#   '127.185090880',
#   '37.549018832'],
#  ['175',
#   '2565',
#   '5',
#   '하남시청(덕풍.신장)',
#   '02-6311-5641',
#   '경기도 하남시 하남대로 지하820(덕풍동)',
#   '경기도 하남시 덕풍동 405-1 하남시청(덕풍신장)역(5호선)',
#   '127.214864237',
#   '37.539277110'],
#  ['176',
#   '2566',
#   '5',
#   '하남검단산',
#   '02-6311-5651',
#   '경기도 하남시 대청로 지하100(창우동)',
#   '경기도 하남시 창우동 526 하남검단산역(5호선)',
#   '126.915512785',
#   '37.598741211'],
#  ['177',
#   '2611',
#   '6',
#   '응암',
#   '02-6311-6101',
#   '서울특별시 은평구 증산로 지하477(신사동)',
#   '서울특별시 은평구 신사동 22-15 응암역(6호선)',
#   '126.926816917',
#   '37.602276104'],
#  ['178',
#   '2612',
#   '6',
#   '역촌',
#   '02-6311-6111',
#   '서울특별시 은평구 서오릉로 지하63(녹번동)',
#   '서울특별시 은평구 녹번동 153-31 역촌역(6호선)',
#   '126.929857627',
#   '37.610136633'],
#  ['179',
#   '2613',
#   '6',
#   '불광',
#   '02-6311-6121',
#   '서울특별시 은평구 통일로 지하723-1(대조동)',
#   '서울특별시 은평구 대조동 13-10 불광역(6호선)',
#   '126.932921971',
#   '37.618305441'],
#  ['180',
#   '2614',
#   '6',
#   '독바위',
#   '02-6311-6131',
#   '서울특별시 은평구 불광로 지하129-1(불광동)',
#   '서울특별시 은평구 불광동 13-33 독바위역(6호선)',
#   '126.936154165',
#   '37.600767190'],
#  ['181',
#   '2615',
#   '6',
#   '연신내',
#   '02-6110-3211',
#   '서울특별시 은평구 통일로 지하849(갈현동)',
#   '서울특별시 은평구 갈현동 397 연신내역(6호선)',
#   '126.916500276',
#   '37.610293374'],
#  ['182',
#   '2616',
#   '6',
#   '구산',
#   '02-6311-6151',
#   '서울특별시 은평구 연서로 지하137-1(구산동)',
#   '서울특별시 은평구 구산동 1 구산역(6호선)',
#   '126.915512785',
#   '37.598741211'],
#  ['183',
#   '2617',
#   '6',
#   '새절(신사)',
#   '02-6311-6161',
#   '서울특별시 은평구 증산로 지하400(신사동)',
#   '서울특별시 은평구 신사동 337-5 새절역(6호선)',
#   '126.915512785',
#   '37.598741211'],
#  ['184',
#   '2618',
#   '6',
#   '증산(명지대앞)',
#   '02-6311-6171',
#   '서울특별시 은평구 증산로 지하306(증산동)',
#   '서울특별시 은평구 증산동 199-8 증산역(6호선)',
#   '126.901865994',
#   '37.577108211'],
#  ['185',
#   '2619',
#   '6',
#   '디지털미디어시티',
#   '02-6311-6181',
#   '서울특별시 은평구 수색로 지하175(증산동)',
#   '서울특별시 은평구 증산동 223-25 디지털미디어시티역(6호선)',
#   '126.901498209',
#   '37.566251594'],
#  ['186',
#   '2620',
#   '6',
#   '월드컵경기장(성산)',
#   '02-6311-6191',
#   '서울특별시 마포구 월드컵로 지하240(성산동)',
#   '서울특별시 마포구 성산동 420 월드컵경기장역(6호선)',
#   '126.881231961',
#   '37.579928641'],
#  ['187',
#   '2621',
#   '6',
#   '마포구청',
#   '02-6311-6201',
#   '서울특별시 마포구 월드컵로 지하190(성산동)',
#   '서울특별시 마포구 성산동 592 마포구청역(6호선)',
#   '126.901498209',
#   '37.566251594'],
#  ['188',
#   '2622',
#   '6',
#   '망원',
#   '02-6311-6211',
#   '서울특별시 마포구 월드컵로 지하77(망원동)',
#   '서울특별시 마포구 망원동 378 망원역(6호선)',
#   '126.918706804',
#   '37.552699027'],
#  ['189',
#   '2623',
#   '6',
#   '합정',
#   '02-6311-6221',
#   '서울특별시 마포구 양화로 지하45(합정동)',
#   '서울특별시 마포구 합정동 414 합정역(6호선)',
#   '126.932055690',
#   '37.547750300'],
#  ['190',
#   '2624',
#   '6',
#   '상수',
#   '02-6311-6231',
#   '서울특별시 마포구 독막로 지하85(상수동)',
#   '서울특별시 마포구 상수동 309-10 상수역(6호선)',
#   '126.924034949',
#   '37.548175546'],
#  ['191',
#   '2625',
#   '6',
#   '광흥창(서강)',
#   '02-6311-6241',
#   '서울특별시 마포구 독막로 지하165(창전동)',
#   '서울특별시 마포구 창전동 145-17 광흥창역(6호선)',
#   '126.942816644',
#   '37.548623274'],
#  ['192',
#   '2626',
#   '6',
#   '대흥(서강대앞)',
#   '02-6311-6251',
#   '서울특별시 마포구 대흥로 지하85(대흥동)',
#   '서울특별시 마포구 대흥동 128-1 대흥역(6호선)',
#   '126.942955728',
#   '37.551163707'],
#  ['193',
#   '2627',
#   '6',
#   '공덕',
#   '02-6311-5291',
#   '서울특별시 마포구 백범로 지하200(공덕동)',
#   '서울특별시 마포구 공덕동 439 공덕역(6호선)',
#   '126.967621237',
#   '37.537220331'],
#  ['194',
#   '2628',
#   '6',
#   '효창공원앞',
#   '02-6311-6271',
#   '서울특별시 용산구 백범로 지하287(효창동)',
#   '서울특별시 용산구 효창동 80 효창공원앞역(6호선)',
#   '126.969190977',
#   '37.530236013'],
#  ['195',
#   '2629',
#   '6',
#   '삼각지',
#   '02-6311-6281',
#   '서울특별시 용산구 한강대로 지하185(한강로1가)',
#   '서울특별시 용산구 한강로1가 228-1 삼각지역(6호선)',
#   '126.993145604',
#   '37.524722107'],
#  ['196',
#   '2630',
#   '6',
#   '녹사평(용산구청)',
#   '02-6311-6291',
#   '서울특별시 용산구 녹사평대로 지하195(용산동4가)',
#   '서울특별시 용산구 용산동4가 4 녹사평역(6호선)',
#   '126.999546262',
#   '37.537354977'],
#  ['197',
#   '2631',
#   '6',
#   '이태원',
#   '02-6311-6301',
#   '서울특별시 용산구 이태원로 지하177(이태원동)',
#   '서울특별시 용산구 이태원동 119-23 이태원역(6호선)',
#   '126.999546262',
#   '37.537354977'],
#  ['198',
#   '2632',
#   '6',
#   '한강진',
#   '02-6311-6311',
#   '서울특별시 용산구 이태원로 지하287(한남동)',
#   '서울특별시 용산구 한남동 726-494 한강진역(6호선)',
#   '127.012866086',
#   '37.550645708'],
#  ['199',
#   '2633',
#   '6',
#   '버티고개',
#   '02-6311-6321',
#   '서울특별시 중구 다산로 지하38(신당동)',
#   '서울특별시 중구 신당동 366-454 버티고개역(6호선)',
#   '127.010875982',
#   '37.562360401'],
#  ['200',
#   '2634',
#   '6',
#   '약수',
#   '02-6311-6331',
#   '서울특별시 중구 다산로 지하115(신당동)',
#   '서울특별시 중구 신당동 369-2 약수역(6호선)',
#   '127.011542754',
#   '37.561163479'],
#  ['201',
#   '2635',
#   '6',
#   '청구',
#   '02-6311-5371',
#   '서울특별시 중구 청구로 지하77(신당동)',
#   '서울특별시 중구 신당동 295-2 청구역(6호선)',
#   '127.010875982',
#   '37.562360401'],
#  ['202',
#   '2636',
#   '6',
#   '신당',
#   '02-6311-6351',
#   '서울특별시 중구 다산로 지하260(흥인동)',
#   '서울특별시 중구 흥인동 162-1 신당역(6호선)',
#   '127.016343073',
#   '37.570718722'],
#  ['203',
#   '2637',
#   '6',
#   '동묘앞',
#   '02-6311-6361',
#   '서울특별시 종로구 지봉로 지하24(숭인동)',
#   '서울특별시 종로구 숭인동 316-3 동묘앞역(6호선)',
#   '127.016343073',
#   '37.570718722'],
#  ['204',
#   '2638',
#   '6',
#   '창신',
#   '02-6311-6371',
#   '서울특별시 종로구 지봉로 지하112(창신동)',
#   '서울특별시 종로구 창신동 20-8 창신역(6호선)',
#   '127.021544867',
#   '37.580641241'],
#  ['205',
#   '2639',
#   '6',
#   '보문',
#   '02-6311-6381',
#   '서울특별시 성북구 보문로 지하116(보문동1가)',
#   '서울특별시 성북구 보문동1가 127-1 보문역(6호선)',
#   '127.023320235',
#   '37.585890516'],
#  ['206',
#   '2640',
#   '6',
#   '안암(고대병원앞)',
#   '02-6311-6391',
#   '서울특별시 성북구 고려대로 지하89(안암동5가)',
#   '서울특별시 성북구 안암동5가 146-1 안암역(6호선)',
#   '127.036388446',
#   '37.597931475'],
#  ['207',
#   '2641',
#   '6',
#   '고려대(종암)',
#   '02-6311-6401',
#   '서울특별시 성북구 종암로 지하1(종암동)',
#   '서울특별시 성북구 종암동 29-18 고려대역(6호선)',
#   '127.042314870',
#   '37.598734615'],
#  ['208',
#   '2642',
#   '6',
#   '월곡(동덕여대)',
#   '02-6311-6411',
#   '서울특별시 성북구 월곡로 지하107(하월곡동)',
#   '서울특별시 성북구 하월곡동 35-1 월곡역(6호선)',
#   '127.053503492',
#   '37.609620572'],
#  ['209',
#   '2643',
#   '6',
#   '상월곡(한국과학기술연구원)',
#   '02-6311-6421',
#   '서울특별시 성북구 화랑로 지하157(상월곡동)',
#   '서울특별시 성북구 상월곡동 26-1 상월곡역(6호선)',
#   '127.047859746',
#   '37.605769417'],
#  ['210',
#   '2644',
#   '6',
#   '돌곶이',
#   '02-6311-6431',
#   '서울특별시 성북구 화랑로 지하243(석관동)',
#   '서울특별시 성북구 석관동 349-8 돌곶이역(6호선)',
#   '127.074291192',
#   '37.617832629'],
#  ['211',
#   '2645',
#   '6',
#   '석계',
#   '02-6311-6441',
#   '서울특별시 노원구 화랑로 지하 347-1(월계동) ',
#   '서울특별시 노원구 월계동 25-2 석계역(6호선)',
#   '127.054947935',
#   '37.679914125'],
#  ['212',
#   '2646',
#   '6',
#   '태릉입구',
#   '02-6311-7171',
#   '서울특별시 노원구 동일로 지하 992-1(공릉동)',
#   '서울특별시 노원구 공릉동 616-4 태릉입구역(6호선)',
#   '127.063496203',
#   '37.614658499'],
#  ['213',
#   '2647',
#   '6',
#   '화랑대(서울여대입구)',
#   '02-6311-6461',
#   '서울특별시 노원구 화랑로 지하510(공릉동)',
#   '서울특별시 노원구 공릉동 285-2 화랑대역(6호선)',
#   '127.097232555',
#   '37.600157181'],
#  ['214',
#   '2648',
#   '6',
#   '봉화산(서울의료원)',
#   '02-6311-6471',
#   '서울특별시 중랑구 신내로 지하232(신내동)',
#   '서울특별시 중랑구 신내동 643-1 봉화산역(6호선)',
#   '127.105095609',
#   '37.611982445'],
#  ['215',
#   '2649',
#   '6',
#   '신내',
#   '02-6311-6481',
#   '서울특별시 중랑구 용마산로136길 33 신내차량기지',
#   '서울특별시 중랑구 신내동 19 신내역(6호선)',
#   '127.053138376',
#   '37.700123584'],
#  ['216',
#   '2711',
#   '7',
#   '장암',
#   '02-6311-7091',
#   '경기도 의정부시 동일로 121(장암동)',
#   '경기도 의정부시 장암동 160-8 장암역(7호선)',
#   '127.046528406',
#   '37.689117008'],
#  ['217',
#   '2712',
#   '7',
#   '도봉산',
#   '02-6311-7101',
#   '서울특별시 도봉구 도봉로 964-40(도봉동)',
#   '서울특별시 도봉구 도봉동 38-3 도봉산역(7호선)',
#   '127.053100390',
#   '37.681327463'],
#  ['218',
#   '2713',
#   '7',
#   '수락산',
#   '02-6311-7111',
#   '서울특별시 노원구 동일로 지하1662(상계동)',
#   '서울특별시 노원구 상계동 1132-9 수락산역(7호선)',
#   '127.054947935',
#   '37.679914125'],
#  ['219',
#   '2714',
#   '7',
#   '마들',
#   '02-6311-7121',
#   '서울특별시 노원구 동일로 지하1530-1(상계동)',
#   '서울특별시 노원구 상계동 650 마들역(7호선)',
#   '127.058738058',
#   '37.669869684'],
#  ['220',
#   '2715',
#   '7',
#   '노원',
#   '02-6311-7131',
#   '서울특별시 노원구 동일로 지하1409(상계동)',
#   '서울특별시 노원구 상계동 729 노원역(7호선)',
#   '127.054947935',
#   '37.679914125'],
#  ['221',
#   '2716',
#   '7',
#   '중계',
#   '02-6311-7141',
#   '서울특별시 노원구 동일로 지하1308-1(중계동)',
#   '서울특별시 노원구 중계동 503-3 중계역(7호선)',
#   '127.055735440',
#   '37.679682128'],
#  ['222',
#   '2717',
#   '7',
#   '하계',
#   '02-6311-7151',
#   '서울특별시 노원구 동일로 지하1196(하계동)',
#   '서울특별시 노원구 하계동 273-5 하계역(7호선)',
#   '127.064478800',
#   '37.643094662'],
#  ['223',
#   '2718',
#   '7',
#   '공릉(서울과학기술대)',
#   '02-6311-7161',
#   '서울특별시 노원구 동일로 지하1074(공릉동)',
#   '서울특별시 노원구 공릉동 385-4 공릉역(7호선)',
#   '127.054947935',
#   '37.679914125'],
#  ['224',
#   '2719',
#   '7',
#   '태릉입구',
#   '02-6311-7171',
#   '서울특별시 노원구 동일로 지하 992-1(공릉동)',
#   '서울특별시 노원구 공릉동 616-4 태릉입구역(7호선)',
#   '127.083379232',
#   '37.590922515'],
#  ['225',
#   '2720',
#   '7',
#   '먹골',
#   '02-6311-7181',
#   '서울특별시 중랑구 동일로 지하901(묵동)',
#   '서울특별시 중랑구 묵동 189-5 먹골역(7호선)',
#   '127.079496624',
#   '37.585772241'],
#  ['226',
#   '2721',
#   '7',
#   '중화',
#   '02-6311-7191',
#   '서울특별시 중랑구 동일로 지하797(중화동)',
#   '서울특별시 중랑구 중화동 50-3 중화역(7호선)',
#   '127.085741819',
#   '37.596709313'],
#  ['227',
#   '2722',
#   '7',
#   '상봉',
#   '02-6311-7201',
#   '서울특별시 중랑구 망우로 297(상봉동)',
#   '서울특별시 중랑구 상봉동 100-9 상봉역(7호선)',
#   '127.092088410',
#   '37.582384273'],
#  ['228',
#   '2723',
#   '7',
#   '면목',
#   '02-6311-7211',
#   '서울특별시 중랑구 면목로 지하407(면목동) ',
#   '서울특별시 중랑구 면목동 282-6 면목역(7호선)',
#   '127.074501875',
#   '37.586082273'],
#  ['229',
#   '2724',
#   '7',
#   '사가정',
#   '02-6311-7221',
#   '서울특별시 중랑구 사가정로 지하393(면목동)',
#   '서울특별시 중랑구 면목동 495 사가정역(7호선)',
#   '127.098158915',
#   '37.592358522'],
#  ['230',
#   '2725',
#   '7',
#   '용마산(용마폭포공원)',
#   '02-6311-7231',
#   '서울특별시 중랑구 용마산로 지하227(면목동)',
#   '서울특별시 중랑구 면목동 1316-5 용마산역(7호선)',
#   '127.082860439',
#   '37.553865695'],
#  ['231',
#   '2726',
#   '7',
#   '중곡',
#   '02-6311-7241',
#   '서울특별시 광진구 능동로 지하417(중곡동)',
#   '서울특별시 광진구 중곡동 273-2 7호선 중곡역(7호선)',
#   '127.074483029',
#   '37.559523160'],
#  ['232',
#   '2727',
#   '7',
#   '군자(능동)',
#   '02-6311-5441',
#   '서울특별시 광진구 천호대로 지하550(능동)',
#   '서울특별시 광진구 능동 275-5 군자(능동)역(7호선)',
#   '127.082860439',
#   '37.553865695'],
#  ['233',
#   '2728',
#   '7',
#   '어린이대공원(세종대)',
#   '02-6311-7261',
#   '서울특별시 광진구 능동로 지하210(화양동)',
#   '서울특별시 광진구 화양동 164-1 어린이대공원역(7호선)',
#   '127.077020319',
#   '37.551691408'],
#  ['234',
#   '2729',
#   '7',
#   '건대입구',
#   '02-6311-7271',
#   '서울특별시 광진구 능동로 지하110(화양동)',
#   '서울특별시 광진구 화양동 6-3 건대입구역(7호선)',
#   '127.066765934',
#   '37.531703551'],
#  ['235',
#   '2730',
#   '7',
#   '자양',
#   '02-6311-7281',
#   '서울특별시 광진구 능동로 10(자양동)',
#   '서울특별시 광진구 자양동 73-2 자양역(7호선)',
#   '127.047387532',
#   '37.517322184'],
#  ['236',
#   '2731',
#   '7',
#   '청담',
#   '02-6311-7291',
#   '서울특별시 강남구 학동로 지하508(청담동)',
#   '서울특별시 강남구 청담동 77-76 청담역(7호선)',
#   '127.047387532',
#   '37.517322184'],
#  ['237',
#   '2732',
#   '7',
#   '강남구청',
#   '02-6311-7301',
#   '서울특별시 강남구 학동로 지하346(삼성동)',
#   '서울특별시 강남구 삼성동 111-44 강남구청역(7호선)',
#   '127.047387532',
#   '37.517322184'],
#  ['238',
#   '2733',
#   '7',
#   '학동',
#   '02-6311-7311',
#   '서울특별시 강남구 학동로 지하180(논현동)',
#   '서울특별시 강남구 논현동 279-67 학동역(7호선)',
#   '127.042994785',
#   '37.517933028'],
#  ['239',
#   '2734',
#   '7',
#   '논현',
#   '02-6311-7321',
#   '서울특별시 강남구 학동로 지하102(논현동)',
#   '서울특별시 강남구 논현동 279-67 논현역(7호선)',
#   '127.013355196',
#   '37.507879138'],
#  ['240',
#   '2735',
#   '7',
#   '반포',
#   '02-6311-7331',
#   '서울특별시 서초구 신반포로 지하241(잠원동)',
#   '서울특별시 서초구 잠원동 103 반포역(7호선)',
#   '127.013355196',
#   '37.507879138'],
#  ['241',
#   '2736',
#   '7',
#   '고속터미널',
#   '02-6311-7341',
#   '서울특별시 서초구 신반포로 지하188(반포동)',
#   '서울특별시 서초구 반포동 19-11 고속터미널역(7호선)',
#   '126.999455102',
#   '37.488668324'],
#  ['242',
#   '2737',
#   '7',
#   '내방',
#   '02-6311-7351',
#   '서울특별시 서초구 서초대로 지하103(방배동)',
#   '서울특별시 서초구 방배동 874-16 내방역(7호선)',
#   '126.975393813',
#   '37.481483165'],
#  ['243',
#   '2738',
#   '7',
#   '이수',
#   '02-6311-7361',
#   '서울특별시 동작구 사당로 지하310(사당동)',
#   '서울특별시 동작구 사당동 144-4 이수역(7호선)',
#   '126.955438392',
#   '37.495320425'],
#  ['244',
#   '2739',
#   '7',
#   '남성',
#   '02-6311-7371',
#   '서울특별시 동작구 사당로 지하218(사당동)',
#   '서울특별시 동작구 사당동 산25-33 남성역(7호선)',
#   '126.947982106',
#   '37.502009055'],
#  ['245',
#   '2740',
#   '7',
#   '숭실대입구(살피재)',
#   '02-6311-7381',
#   '서울특별시 동작구 상도로 지하378(상도동)',
#   '서울특별시 동작구 상도동 514 숭실대입구역(7호선)',
#   '126.947982106',
#   '37.502009055'],
#  ['246',
#   '2741',
#   '7',
#   '상도',
#   '02-6311-7391',
#   '서울특별시 동작구 상도로 지하272(상도1동)',
#   '서울특별시 동작구 상도1동 702-1 상도역(중대입구역)(7호선)',
#   '126.947982106',
#   '37.502009055'],
#  ['247',
#   '2742',
#   '7',
#   '장승배기',
#   '02-6311-7401',
#   '서울특별시 동작구 상도로 지하188(상도동) ',
#   '서울특별시 동작구 상도동 26-20 장승배기역(7호선)',
#   '126.947982106',
#   '37.502009055'],
#  ['248',
#   '2743',
#   '7',
#   '신대방삼거리',
#   '02-6311-7411',
#   '서울특별시 동작구 상도로 지하76(대방동)',
#   '서울특별시 동작구 대방동 406-10 신대방삼거리역(7호선)',
#   '126.942300144',
#   '37.505468982'],
#  ['249',
#   '2744',
#   '7',
#   '보라매',
#   '02-6311-7421',
#   '서울특별시 동작구 상도로 지하2(대방동)',
#   '서울특별시 동작구 대방동 466-51 보라매역(7호선)',
#   '126.906319481',
#   '37.500543286'],
#  ['250',
#   '2745',
#   '7',
#   '신풍',
#   '02-6311-7431',
#   '서울특별시 영등포구 신풍로 지하27(신길동)',
#   '서울특별시 영등포구 신길동 3599 신풍역(7호선)',
#   '126.905219563',
#   '37.501636534'],
#  ['251',
#   '2746',
#   '7',
#   '대림(구로구청)',
#   '02-6311-7441',
#   '서울특별시 영등포구 도림로 지하137(대림동)',
#   '서울특별시 영등포구 대림동 1050-17 대림역(7호선)',
#   '126.887363256',
#   '37.486190898'],
#  ['252',
#   '2747',
#   '7',
#   '남구로',
#   '02-6311-7451',
#   '서울특별시 구로구 도림로 지하7(구로동) ',
#   '서울특별시 구로구 구로동 801-95 남구로역(7호선)',
#   '126.882128952',
#   '37.482290922'],
#  ['253',
#   '2748',
#   '7',
#   '가산디지털단지',
#   '02-6311-7461',
#   '서울특별시 금천구 벚꽃로 309(가산동)',
#   '서울특별시 금천구 가산동 468-4 가산디지털단지역(7호선)',
#   '126.866292909',
#   '37.476049873'],
#  ['254',
#   '2749',
#   '7',
#   '철산',
#   '02-6311-7471',
#   '경기도 광명시 철산로 지하13(철산동)',
#   '경기도 광명시 철산동 526 철산역(7호선)',
#   '126.869152039',
#   '37.465176709'],
#  ['255',
#   '2750',
#   '7',
#   '광명사거리',
#   '02-6311-7481',
#   '경기도 광명시 오리로 지하980(광명동)',
#   '경기도 광명시 광명동 158-211 광명사거리역(7호선)',
#   '126.829543076',
#   '37.496264850'],
#  ['256',
#   '2751',
#   '7',
#   '천왕',
#   '02-6311-7491',
#   '서울특별시 구로구 오리로 지하1154(천왕동)',
#   '서울특별시 구로구 천왕동 14-25 천왕역(7호선)',
#   '126.822528760',
#   '37.491549394'],
#  ['257',
#   '2752',
#   '7',
#   '온수(성공회대입구)',
#   '02-6311-7501',
#   '서울특별시 구로구 경인로3길 지하64(온수동)',
#   '서울특별시 구로구 온수동 119 온수역(7호선)',
#   '127.127069591',
#   '37.548022852'],
#  ['259',
#   '2811',
#   '8',
#   '암사',
#   '02-6311-8101',
#   '서울특별시 강동구 올림픽로 지하776(암사동)',
#   '서울특별시 강동구 암사동 501 암사역(8호선)',
#   '126.8214750096839',
#   '37.49141104008795'],
#  ['258',
#   '2810',
#   '8',
#   '암사역사공원역',
#   '02-6311-8091',
#   '서울특별시 강동구 아리수로 27번길 2(암사동) ',
#   '서울특별시 강동구 암사동 378 암사역사공원역(8호선)',
#   '127.124449131',
#   '37.538987633'],
#  ['260',
#   '2812',
#   '8',
#   '천호(풍납토성)',
#   '02-6311-5471',
#   '서울특별시 강동구 천호대로 지하997(천호동)',
#   '서울특별시 강동구 천호동 455 천호역(8호선)',
#   '127.127069591',
#   '37.548022852'],
#  ['261',
#   '2813',
#   '8',
#   '강동구청',
#   '02-6311-8121',
#   '서울특별시 강동구 올림픽로 지하550(성내동)',
#   '서울특별시 강동구 성내동 319 강동구청역(8호선)',
#   '127.086375269',
#   '37.511591761'],
#  ['262',
#   '2814',
#   '8',
#   '몽촌토성(평화의문)',
#   '02-6311-8131',
#   '서울특별시 송파구 올림픽로 지하383(신천동)',
#   '서울특별시 송파구 신천동 19 몽촌토성역(8호선)',
#   '127.104237421',
#   '37.514987918'],
#  ['263',
#   '2815',
#   '8',
#   '잠실(송파구청)',
#   '02-6311-8141',
#   '서울특별시 송파구 올림픽로 305(신천동)',
#   '서울특별시 송파구 신천동 7-4 잠실역(8호선)',
#   '127.126101605',
#   '37.479849258'],
#  ['264',
#   '2816',
#   '8',
#   '석촌',
#   '02-6311-8151',
#   '서울특별시 송파구 송파대로 지하439(석촌동)',
#   '서울특별시 송파구 석촌동 209 석촌역(8호선)',
#   '127.126101605',
#   '37.479849258'],
#  ['265',
#   '2817',
#   '8',
#   '송파',
#   '02-6311-8161',
#   '서울특별시 송파구 송파대로 지하354(가락동)',
#   '서울특별시 송파구 가락동 459-4 송파역(8호선)',
#   '127.096078784',
#   '37.516719214'],
#  ['266',
#   '2818',
#   '8',
#   '가락시장',
#   '02-6311-8171',
#   '서울특별시 송파구 송파대로 지하257(가락동)',
#   '서울특별시 송파구 가락동 184-23 가락시장역(8호선)',
#   '127.095480215',
#   '37.515545741'],
#  ['267',
#   '2819',
#   '8',
#   '문정',
#   '02-6311-8181',
#   '서울특별시 송파구 송파대로 지하179(문정동)',
#   '서울특별시 송파구 문정동 119-4 문정역(8호선)',
#   '127.126101605',
#   '37.479849258'],
#  ['268',
#   '2820',
#   '8',
#   '장지',
#   '02-6311-8191',
#   '서울특별시 송파구 송파대로 지하82(장지동)',
#   '서울특별시 송파구 장지동 201-5 장지역(8호선)',
#   '127.117646591',
#   '37.496304967'],
#  ['269',
#   '2821',
#   '8',
#   '복정',
#   '02-6311-8201',
#   '서울특별시 송파구 송파대로 지하6(장지동)',
#   '서울특별시 송파구 장지동 596-21 복정역(8호선)',
#   '127.139297285',
#   '37.463087443'],
#  ['270',
#   '2828',
#   '8',
#   '남위례',
#   '02-6311-8211',
#   '경기도 성남시 수정구 공원로 601(복정동)',
#   '경기도 성남시 수정구 복정동 57 남위례역(8호선)',
#   '127.146017234',
#   '37.450333650'],
#  ['271',
#   '2822',
#   '8',
#   '산성',
#   '02-6311-8221',
#   '경기도 성남시 수정구 수정로 지하365(신흥동)',
#   '경기도 성남시 수정구 신흥동 7 산성역(8호선)',
#   '127.162654550',
#   '37.456943716'],
#  ['272',
#   '2823',
#   '8',
#   '남한산성입구(성남법원.검찰청)',
#   '02-6311-8231',
#   '경기도 성남시 수정구 산성대로 지하445(단대동)',
#   '경기도 성남시 수정구 단대동 96 남한산성입구역(8호선)',
#   '127.162654550',
#   '37.456943716'],
#  ['273',
#   '2824',
#   '8',
#   '단대오거리',
#   '02-6311-8241',
#   '경기도 성남시 수정구 산성대로 지하365(신흥동)',
#   '경기도 성남시 수정구 신흥동 2467 단대오거리역(8호선)',
#   '127.162654550',
#   '37.456943716'],
#  ['274',
#   '2825',
#   '8',
#   '신흥',
#   '02-6311-8251',
#   '경기도 성남시 수정구 산성대로 지하280(신흥동)',
#   '경기도 성남시 수정구 신흥동 2467 신흥역(8호선)',
#   '127.162654550',
#   '37.456943716'],
#  ['275',
#   '2826',
#   '8',
#   '수진',
#   '02-6311-8261',
#   '경기도 성남시 수정구 산성대로 지하200(수진동)',
#   '경기도 성남시 수정구 수진동 2205-1 수진역(8호선)',
#   '127.162654550',
#   '37.456943716'],
#  ['276',
#   '2827',
#   '8',
#   '모란',
#   '02-6311-8271',
#   '경기도 성남시 수정구 산성대로 지하100(수진동)',
#   '경기도 성남시 수정구 수진동 4518 모란역(8호선)',
#   '127.064186828',
#   '37.515170561'],
#  ['277',
#   '4126',
#   '9',
#   '언주',
#   '02-2656-0926',
#   '서울특별시 강남구 봉은사로 지하201(논현동)',
#   '서울특별시 강남구 논현동 279-165 언주역(9호선)',
#   '127.056507774',
#   '37.486213104'],
#  ['278',
#   '4127',
#   '9',
#   '선정릉',
#   '02-2656-0927',
#   '서울특별시 강남구 선릉로 지하580(삼성동)',
#   '서울특별시 강남구 삼성동 111-114 선정릉역(9호선)',
#   '127.064186828',
#   '37.515170561'],
#  ['279',
#   '4128',
#   '9',
#   '삼성중앙',
#   '02-2656-0928',
#   '서울특별시 강남구 봉은사로 지하501(삼성동)',
#   '서울특별시 강남구 삼성동 111-147 삼성중앙역(9호선)',
#   '127.064186828',
#   '37.515170561'],
#  ['280',
#   '4129',
#   '9',
#   '봉은사',
#   '02-2656-0929',
#   '서울특별시 강남구 봉은사로 지하601(삼성동)',
#   '서울특별시 강남구 삼성동 172 봉은사역(9호선)',
#   '127.076256669',
#   '37.511447966'],
#  ['281',
#   '4130',
#   '9',
#   '종합운동장',
#   '02-2656-0930',
#   '서울특별시 송파구 올림픽로 49(잠실동)',
#   '서울특별시 송파구 잠실동 123 종합운동장역(9호선)',
#   '127.107414398',
#   '37.503103936'],
#  ['282',
#   '4131',
#   '9',
#   '삼전',
#   '02-2656-0931',
#   '서울특별시 송파구 백제고분로 지하189(잠실동)',
#   '서울특별시 송파구 잠실동 347 삼전역(9호선)',
#   '127.107414398',
#   '37.503103936'],
#  ['283',
#   '4132',
#   '9',
#   '석촌고분',
#   '02-2656-0932',
#   '서울특별시 송파구 백제고분로 지하274(삼전동)',
#   '서울특별시 송파구 삼전동 157-1 석촌고분역(9호선)',
#   '127.126101605',
#   '37.479849258'],
#  ['284',
#   '4133',
#   '9',
#   '석촌',
#   '02-2656-0933',
#   '서울특별시 송파구 송파대로 지하439(석촌동)',
#   '서울특별시 송파구 석촌동 209 석촌역(9호선)',
#   '127.101061494',
#   '37.502815623'],
#  ['285',
#   '4134',
#   '9',
#   '송파나루',
#   '02-2656-0934',
#   '서울특별시 송파구 백제고분로 지하446(방이동)',
#   '서울특별시 송파구 방이동 2 송파나루역(9호선)',
#   '127.118345402',
#   '37.512011982'],
#  ['286',
#   '4135',
#   '9',
#   '한성백제',
#   '02-2656-0935',
#   '서울특별시 송파구 위례성대로 지하29(방이동)',
#   '서울특별시 송파구 방이동 88-17 한성백제역(9호선)',
#   '127.134326509',
#   '37.515450096'],
#  ['287',
#   '4136',
#   '9',
#   '올림픽공원(한국체대)',
#   '02-2656-0936',
#   '서울특별시 송파구 양재대로 지하1233(방이동)',
#   '서울특별시 송파구 방이동 89-28 올림픽공원역(9호선)',
#   '127.132180703',
#   '37.524208018'],
#  ['288',
#   '4137',
#   '9',
#   '둔촌오륜',
#   '02-2656-0937',
#   '서울특별시 강동구 강동대로 지하303(둔촌동)',
#   '서울특별시 강동구 둔촌동 227-7 둔촌오륜역(9호선)',
#   '127.144364997',
#   '37.517427151']]

# %% [markdown]
# ## 05. 변환 결과 저장하기

# %% [markdown]
# ### 데이터프레임으로 변환

# %%
new_resultset = []

for r in resultset:
    item_dict = {
        "연변": r[0],
        "역번호": r[1],
        "호선": r[2],
        "역명": r[3],
        "역전화번호": r[4],
        "도로명주소": r[5],
        "지번주소": r[6],
        "위도": r[7],
        "경도": r[8]
    }

    new_resultset.append(item_dict)

df = DataFrame(new_resultset)
df.to_excel("지하철역.xlsx")
df
# Out:
#       연변   역번호  ...                  위도                  경도
# 0     연번   역번호  ...  127.14834880144522  37.528334424738375
# 1      1   150  ...       126.978346780        37.566700969
# 2      2   151  ...       127.022379505        37.573411520
# 3      3   152  ...       127.022379505        37.573411520
# 4      4   153  ...       127.022379505        37.573411520
# ..   ...   ...  ...                 ...                 ...
# 284  284  4133  ...       127.101061494        37.502815623
# 285  285  4134  ...       127.118345402        37.512011982
# 286  286  4135  ...       127.134326509        37.515450096
# 287  287  4136  ...       127.132180703        37.524208018
# 288  288  4137  ...       127.144364997        37.517427151
#
# [289 rows x 9 columns]

# %% [markdown]
# ### 변환결과 엑셀로 저장

# %%
df.to_excel("지하철역_위치.xlsx")
